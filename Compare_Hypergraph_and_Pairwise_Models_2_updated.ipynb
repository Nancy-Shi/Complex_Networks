# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancy-Shi/Complex_Networks/blob/main/Compare_Hypergraph_and_Pairwise_Models_2_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following code is used to demonstrate the result of hypergraph rumor spread on a network. In this example, the network size is 400, with degree exponent of 2.5, and minimum degree of 3. The number of hyperedges (groups) is set to 100. The heatmap shows the stifler density with varying transmission rate while setting the threshold constant to 0.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import random
import math as math
from math import log
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Part 1: Hypergraph Generation
# The following steps generate a hyper graph using the XGI/HyperNetX python package,  following power-law degree distribution for predifined number of nodes n, number of hyperedges num_hyper_edges, degree exponent gamma, using a configuration model with data stored in a dictionary.

# %%
# Step 1: Generate Degree Sequence
def generate_degree_sequence(n, gamma, kmin):
    # Generate a random set from the power law distribution
    u = np.random.uniform(size=n)
    degrees = np.ceil((1.0 - u) ** (-1.0 / (gamma - 1.0)))

    # Adjust degrees based on the minimum and maximum degree values
    kmax = int(np.sqrt(n))
    # kmax = int(1.5*n**(1/4)) # max degree allowed is 1.5*n^(1/4)
    degrees = degrees[(degrees >= kmin) & (degrees <= kmax)].astype(int)

    # Truncate or pad the sequence to match the length specified
    if len(degrees) >= n:
        degrees = degrees[:n]
    else:
        degrees = np.concatenate((degrees, np.full(n - len(degrees), kmin)))

    return degrees.tolist()

# Step 2: Generate Hyper Edge Size Sequence
def generate_hyper_edge_sizes(degrees, num_hyper_edges):
    total_degrees = sum(degrees)
    hyper_edge_sizes = []

    # Calculate the average size for each hyper edge
    avg_size = total_degrees // num_hyper_edges
    remainder = total_degrees % num_hyper_edges

    # Define the range for the random distribution
    min_size = 1  # Lower bound of the range
    max_size = len(degrees)-num_hyper_edges  # Upper bound of the range

    # Generate hyper edge sizes
    for _ in range(num_hyper_edges):
        size = random.randint(min_size, max_size)
        hyper_edge_sizes.append(size)

    return hyper_edge_sizes


# Step 3: Create Copies of Nodes
def create_node_copies(degrees):
    node_copies = []
    for i, degree in enumerate(degrees):
        for _ in range(degree):
            node_copies.append(i)
    return node_copies

# Step 4: Create Copies of Hyper Edges
def create_hyper_edge_copies(hyper_edge_sizes):
    hyper_edge_copies = []
    for i, size in enumerate(hyper_edge_sizes):
        for _ in range(size):
            hyper_edge_copies.append(i)
    return hyper_edge_copies

# Step 5: Randomly Pair Copies
def randomly_pair_copies(node_copies, hyper_edge_copies):
    random.shuffle(node_copies)
    random.shuffle(hyper_edge_copies)
    pairs = []
    for i in range(len(node_copies)):
        pairs.append((node_copies[i], hyper_edge_copies[i]))
    return pairs

# Step 6: Convert Bipartite Graph to A Hypergraph Dictionary
def convert_to_hypergraph(pairs):
    hypergraph = {}
    for pair in pairs:
        node, hyper_edge = pair
        if hyper_edge in hypergraph:
            hypergraph[hyper_edge].append(node)
        else:
            hypergraph[hyper_edge] = [node]
    return hypergraph

# %%
def build_hypergraph(n, gamma, kmin, num_hyper_edges):
    # Step 1: Generate Degree Sequence
    degrees = generate_degree_sequence(n, gamma, kmin)
    print("Degree Sequence: ", degrees)

    # Step 2: Generate Hyper Edge Size Sequence
    hyper_edge_sizes = generate_hyper_edge_sizes(degrees, num_hyper_edges)
    print("Hyper Edge Sizes: ", hyper_edge_sizes)

    # Step 3: Create Copies of Nodes
    node_copies = create_node_copies(degrees)

    # Step 4: Create Copies of Hyper Edges
    hyper_edge_copies = create_hyper_edge_copies(hyper_edge_sizes)

    # Step 5: Randomly Pair Copies
    pairs = randomly_pair_copies(node_copies, hyper_edge_copies)

    # Step 6: Convert Bipartite Graph to Hypergraph
    hyperedge_dict = convert_to_hypergraph(pairs)

    # Print the resulting hypergraph
    print("Hypergraph Dictionary: ", hyperedge_dict)

    return degrees, hyperedge_dict

# %%
# Test 1
n =50  # Number of nodes
gamma = 2.5  # Power-law exponent
kmin = 3  # Minimum degree
num_hyper_edges = 8  # Desired number of hyper edges

degrees, hyperedge_dict = build_hypergraph(n, gamma, kmin, num_hyper_edges)
# Out:
# Degree Sequence:  [4, 5, 3, 5, 6, 4, 3, 3, 5, 3, 3, 6, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [6, 33, 38, 9, 25, 35, 4, 31]
# Hypergraph Dictionary:  {7: [29, 27, 28, 35, 36, 6, 1, 32, 8, 49, 22, 4, 44, 18, 36, 27, 8, 35, 48, 11, 19, 1, 11, 1, 49, 23, 16, 44], 1: [26, 7, 33, 34, 10, 29, 14, 25, 6, 2, 7, 31, 35, 5, 8, 4, 2, 33, 4, 11, 21, 37, 17, 3, 10, 22, 9, 25, 34, 11], 5: [19, 26, 12, 37, 3, 27, 30, 45, 43, 18, 5, 24, 28, 15, 30, 45, 19, 13, 8, 10, 17, 41, 6, 21, 47, 15, 18, 41, 1, 38, 46], 2: [9, 41, 13, 34, 39, 12, 32, 3, 11, 38, 39, 5, 49, 22, 47, 8, 24, 40, 46, 40, 37, 48, 40, 14, 17, 3, 20, 33, 4, 9, 29, 12, 23, 7], 4: [4, 44, 20, 43, 0, 31, 1, 42, 13, 3, 0, 28, 45, 4, 39, 21, 25, 5, 30, 11, 46, 16, 47], 3: [23, 15, 0, 43, 24, 14, 31, 32], 6: [16, 36, 26, 2], 0: [20, 42, 48, 38, 42, 0]}

# %%
# Plot the hypergraph
# !pip install hypernetx
import hypernetx as hnx
H = hnx.Hypergraph(hyperedge_dict)
plt.subplots(figsize=(5,5))
hnx.draw(H)
# Out:
# Collecting hypernetx
#   Downloading hypernetx-2.0.2-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.5/95.5 kB 5.6 MB/s eta 0:00:00
# Collecting networkx<3.0,>=2.2 (from hypernetx)
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.7 MB/s eta 0:00:00
# Collecting numpy<2.0,>=1.24.0 (from hypernetx)
#   Downloading numpy-1.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.10.1)
# Requirement already satisfied: matplotlib>3.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.2.2)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.5.3)
# Collecting decorator>=5.1.1 (from hypernetx)
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->hypernetx) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->hypernetx) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->hypernetx) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>3.0->hypernetx) (1.16.0)
# Installing collected packages: numpy, networkx, decorator, hypernetx
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.1 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.1 which is incompatible.
# Successfully installed decorator-5.1.1 hypernetx-2.0.2 networkx-2.8.8 numpy-1.25.1
#  No module named 'igraph'. If you need to use hypernetx.algorithms.hypergraph_modularity, please install additional packages by running the following command: pip install .['all']

# %%
# Test 2
n2 =400  # Number of nodes
gamma2 = 2.5  # Power-law exponent
kmin2 = 3  # Minimum degree
num_hyper_edges2 = 100  # Desired number of hyper edges

degrees2, hyperedge_dict2 = build_hypergraph(n2, gamma2, kmin2, num_hyper_edges2)
H2 = hnx.Hypergraph(hyperedge_dict2)
# Out:
# Degree Sequence:  [3, 4, 3, 7, 6, 3, 3, 3, 4, 3, 3, 3, 8, 3, 4, 3, 3, 3, 3, 8, 5, 3, 3, 11, 3, 3, 6, 5, 7, 3, 8, 17, 4, 5, 3, 3, 3, 9, 3, 5, 3, 3, 3, 3, 3, 3, 3, 6, 3, 4, 10, 3, 3, 3, 4, 4, 3, 7, 3, 4, 3, 9, 4, 3, 3, 6, 3, 7, 6, 14, 3, 6, 4, 3, 3, 4, 3, 4, 3, 3, 13, 3, 3, 4, 8, 5, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 6, 4, 3, 3, 3, 3, 3, 15, 10, 16, 8, 4, 3, 14, 3, 5, 3, 16, 3, 3, 7, 4, 4, 5, 7, 8, 10, 3, 4, 3, 9, 3, 3, 3, 10, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [54, 129, 234, 196, 297, 161, 79, 11, 66, 92, 75, 154, 110, 179, 154, 99, 8, 64, 158, 54, 69, 100, 12, 299, 249, 114, 214, 35, 104, 34, 230, 243, 130, 269, 35, 17, 80, 266, 8, 64, 113, 219, 21, 185, 93, 205, 117, 76, 28, 283, 27, 19, 165, 143, 60, 150, 91, 192, 166, 292, 131, 82, 55, 113, 56, 274, 41, 22, 98, 74, 11, 24, 94, 231, 33, 63, 266, 114, 12, 78, 249, 17, 157, 275, 218, 208, 41, 95, 190, 109, 131, 290, 47, 165, 113, 227, 287, 223, 169, 284]
# Hypergraph Dictionary:  {57: [366, 236, 21, 86, 286, 306, 104, 187, 279, 115, 384, 12, 169, 31, 200, 85, 307, 268, 116], 15: [28, 62, 380, 369, 37, 335, 105, 31, 398, 272, 122, 51, 284, 78], 46: [317, 120, 18, 120, 103, 340, 110, 154, 204, 190, 246], 18: [123, 130, 368, 128, 59, 167, 92, 42, 345, 61, 395, 349, 327, 210], 40: [4, 382, 321, 69, 118, 363, 37, 262, 32, 68, 267, 157], 37: [379, 259, 295, 393, 72, 47, 119, 69, 96, 369, 55, 56, 103, 296, 20, 198, 35, 247, 357, 143, 113, 120, 13, 154, 80, 103, 258, 106, 298, 105, 88, 158, 26, 59, 49, 120], 80: [192, 11, 216, 399, 199, 106, 53, 52, 6, 130, 245, 50, 95, 102, 47, 105, 6, 360, 42, 80, 364, 186, 45, 152, 58, 328, 89, 251, 275], 67: [121, 205, 88], 94: [130, 97, 347, 130, 197, 12, 100, 274, 333, 157, 334, 385, 126, 177, 320, 238, 330], 12: [385, 80, 284, 72, 235, 297, 302, 130, 251, 14, 24, 61, 269, 162, 296], 88: [237, 117, 33, 201, 278, 7, 248, 69, 46, 139, 308, 279, 299, 317, 372, 241, 122, 396], 58: [332, 248, 27, 243, 113, 358, 264, 46, 3, 35, 221, 393, 288, 256, 110, 303, 98, 80, 230], 41: [228, 1, 168, 86, 231, 25, 320, 109, 67, 36, 130, 360, 23, 13, 109, 122, 105, 295, 104], 59: [271, 33, 118, 69, 65, 111, 354, 66, 3, 153, 153, 77, 33, 77, 50, 126, 323, 204, 28, 84, 46, 189, 377, 370, 11, 136, 60, 125, 296, 80, 247, 189], 11: [81, 108, 104, 23, 1, 47, 80, 67, 305, 355, 20, 274, 104, 343, 142, 19], 61: [104, 166, 149, 43, 396, 282, 358, 79, 394, 307, 339], 85: [324, 32, 131, 53, 218, 109, 202, 378, 25, 359, 121, 25, 26, 349, 89, 104, 245, 94, 173, 122, 49, 35, 272, 277], 27: [104, 134, 319, 108, 297, 69], 34: [136, 121, 148, 248, 107, 334], 77: [351, 325, 342, 26, 80, 273, 31, 240, 297, 24, 277, 19], 73: [311, 347, 240, 16, 190, 94, 337, 74, 113, 40, 274, 213, 29, 149, 362, 395, 12, 90, 137, 69, 388, 20, 174, 160, 28, 105, 113, 166], 70: [308, 103, 270, 243, 82], 13: [156, 93, 305, 375, 252, 178, 289, 230, 148, 190, 223, 111, 162, 155, 194, 23, 238], 98: [38, 179, 365, 366, 109, 10, 198, 242, 249, 290, 17, 224, 203, 122, 29, 60, 159, 139, 257, 244, 76, 295, 167, 342, 84, 318], 71: [102, 377], 76: [390, 61, 23, 304, 266, 329, 250, 13, 65, 361, 116, 214, 73, 233, 160, 111, 348, 132, 381, 138, 115, 257, 109, 127], 45: [33, 385, 313, 90, 341, 157, 31, 312, 57, 81, 150, 65, 272, 215, 299, 67, 388, 60, 276, 324, 109, 170, 178, 221, 217, 365, 48, 200], 87: [80, 146, 16, 335, 121, 253, 202, 175, 126, 392], 35: [43, 10, 343, 253, 315, 268], 91: [2, 38, 289, 284, 125, 36, 69, 341, 30, 234, 209, 22, 32, 28, 300, 9, 126, 323, 30, 314, 32, 49, 52, 72, 218, 250, 354, 145, 245, 129, 311, 105, 8, 374], 38: [63], 14: [348, 99, 287, 191, 130, 31, 339, 195, 84, 241, 281, 171, 113, 47, 225, 132, 26, 227, 142, 27, 372, 122], 4: [345, 294, 61, 28, 344, 314, 116, 57, 301, 355, 240, 127, 67, 175, 44, 74, 144, 90, 312, 142, 48, 341, 27, 397, 91, 335, 4, 8, 126, 292, 117, 367, 130, 129, 50], 90: [300, 86, 4, 28, 399, 47, 384, 260, 262, 24, 309, 176, 64, 105, 137], 49: [365, 67, 168, 65, 50, 345, 316, 208, 31, 58, 94, 351, 294, 207, 29, 181, 84, 266, 214, 106, 23, 346, 354, 105, 126, 383, 337, 31], 23: [356, 239, 393, 152, 267, 210, 3, 71, 92, 223, 376, 45, 19, 254, 371, 45, 77, 164, 346, 96, 140, 249, 381, 202, 161, 301, 238, 231, 98, 350, 39, 353, 216, 330, 191, 93, 392, 114, 293, 233, 325], 60: [172, 61, 236, 155, 20, 309, 75, 44, 226, 362, 126, 206, 69, 249], 82: [4, 265, 113, 213, 54, 176, 390, 182, 366, 378, 368, 132, 103, 234, 278], 24: [57, 170, 52, 193, 103, 359, 39, 268, 313, 280, 182, 96, 19, 22, 124, 98, 344, 211, 271, 323, 17, 1, 124, 363, 23, 331, 127, 119, 103, 139], 33: [66, 19, 261, 196, 214, 80, 51, 61, 236, 276, 227, 36, 3, 198, 173, 211, 0, 156, 259, 302, 352, 72, 197, 95, 54, 111, 85, 14, 34, 319, 141, 185, 380, 143], 43: [219, 180, 12, 291, 131, 83, 107, 103, 0, 232, 95, 287, 7, 31, 2, 117, 62, 53, 61, 216, 113, 161, 80], 93: [116, 11, 133, 5, 51, 235, 37, 5, 242, 27, 128, 1, 106, 44, 109, 217, 291], 30: [304, 23, 70, 265, 232, 344, 14, 154, 338, 285, 113, 310, 63, 352, 1 ...

# %%
# Test 3
n3 =400  # Number of nodes
gamma3 = 2.5  # Power-law exponent
kmin3 = 3  # Minimum degree
num_hyper_edges3 = 100  # Desired number of hyper edges

degrees3, hyperedge_dict3 = build_hypergraph(n3, gamma3, kmin3, num_hyper_edges3)
H3 = hnx.Hypergraph(hyperedge_dict3)
# Out:
# Degree Sequence:  [3, 4, 3, 3, 3, 4, 4, 3, 6, 3, 16, 5, 3, 3, 15, 9, 6, 5, 6, 18, 13, 3, 3, 3, 3, 5, 3, 3, 3, 3, 3, 3, 5, 5, 8, 3, 3, 6, 3, 3, 3, 9, 3, 6, 3, 4, 3, 4, 3, 3, 7, 3, 3, 3, 4, 4, 3, 4, 4, 3, 12, 3, 5, 4, 3, 4, 5, 3, 3, 4, 3, 7, 9, 4, 3, 3, 3, 3, 7, 5, 5, 6, 3, 3, 3, 6, 3, 4, 4, 18, 3, 3, 3, 3, 9, 4, 5, 3, 3, 3, 4, 12, 8, 4, 5, 3, 7, 4, 5, 5, 4, 3, 10, 6, 8, 3, 3, 3, 4, 4, 6, 3, 7, 3, 3, 11, 4, 3, 3, 6, 3, 3, 4, 3, 3, 3, 3, 3, 12, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [119, 118, 79, 232, 170, 296, 15, 239, 72, 127, 77, 126, 279, 281, 83, 89, 271, 47, 169, 152, 192, 54, 2, 42, 83, 50, 204, 97, 84, 72, 121, 228, 293, 300, 269, 162, 262, 104, 99, 197, 136, 106, 79, 45, 99, 156, 231, 38, 20, 233, 32, 189, 90, 68, 87, 157, 253, 188, 124, 52, 168, 151, 272, 132, 141, 255, 74, 113, 160, 175, 109, 182, 259, 38, 281, 18, 91, 151, 86, 42, 164, 86, 141, 136, 261, 30, 16, 26, 220, 179, 33, 14, 200, 121, 71, 274, 278, 101, 22, 46]
# Hypergraph Dictionary:  {74: [91, 211, 14, 234, 123, 172, 187, 263, 196, 398, 20, 62, 79, 138, 319, 215, 93, 104, 390, 18, 28, 319, 295, 132, 282, 236, 72, 14, 378, 155, 335, 271, 101, 101, 228, 101, 43], 92: [104, 263, 8, 137, 41, 246, 43, 241, 121, 319, 109, 21, 116, 315, 373, 138, 262, 138, 174, 89, 381, 119, 227, 332, 248, 189, 237], 33: [86, 94, 285, 109, 1, 242, 110, 85, 181, 346, 27, 188, 109, 14, 261, 357, 330, 216, 19, 84, 119, 154, 286, 202, 373, 79, 289, 330, 261, 374, 123, 99, 19, 178, 96, 23, 299, 94, 15, 25, 63], 93: [117, 285, 60, 38, 329, 33, 370], 72: [24, 360, 60, 249, 89, 396, 247, 51, 0, 62, 195, 173, 210, 271, 63, 90, 333, 72, 16, 349, 252, 14, 57, 62, 27, 106, 262, 341, 383, 371, 14, 111], 44: [229, 342, 3, 83, 114, 10, 53, 190, 363, 122, 57, 142], 55: [342, 80, 205, 339, 87, 304, 7, 35, 283, 338, 45, 3, 10], 89: [201, 384, 96, 182, 89, 392, 49, 258, 32, 124, 45, 98, 385, 347, 242, 221, 226, 212, 278, 163, 85], 97: [86, 10, 68, 254, 345, 161, 108, 175, 118, 170, 187, 221, 279, 397, 350], 96: [19, 19, 241, 231, 226, 34, 21, 273, 48, 256, 222, 349, 338, 227, 245, 179, 282, 77, 54, 222, 60, 80, 366, 106, 233, 152, 95, 292, 81, 19, 351, 42, 128, 125, 320], 67: [194, 10, 125, 279, 41, 357, 89, 10, 249, 225, 60], 30: [74, 203, 37, 36, 50, 137, 93, 248, 396, 41], 57: [208, 130, 89, 16, 114, 171, 313, 41, 72, 343, 217, 235, 192, 15], 7: [104, 138, 15, 89, 230, 353, 374, 96, 370, 397, 107, 113, 156, 157, 193, 91, 0, 80, 84, 268, 141, 162, 81, 47, 329, 282], 15: [70, 286, 69, 308, 287, 125, 78], 60: [96, 324, 35, 349, 36, 381, 113, 94, 243, 78, 277, 10, 339, 143, 184, 395, 341, 328, 46, 351, 38], 68: [51, 388, 222, 276, 198, 383, 265, 201, 140, 135, 389, 197, 33, 134, 245, 72, 162], 56: [94, 309, 218, 81, 348, 154, 307, 8, 113, 295, 139, 37, 240, 170, 93, 66, 136, 192, 318, 129, 101, 102, 20, 29, 122, 56, 347, 113], 13: [40, 54, 15, 157, 58, 260, 145, 156, 138, 304, 365, 283, 205, 12, 184, 125, 363, 240, 322, 126, 279, 41, 309, 253, 25, 29, 334, 10, 188, 19, 71, 189, 85, 293], 19: [5, 99, 188, 210, 32, 317, 59, 398, 23, 151, 323, 249, 78, 352], 88: [241, 303, 208, 7, 106, 138, 255, 71, 191, 254, 127, 209, 292, 217, 371, 382, 227, 164, 377, 394, 108, 155], 64: [274, 207, 297, 281, 214, 275, 73, 20, 367], 3: [296, 344, 124, 334, 114, 379, 162, 201, 376, 120, 276, 139, 170, 4, 352, 306, 214, 301, 252, 147, 1, 17, 119, 115, 184, 355, 179, 125, 234], 62: [89, 72, 214, 35, 149, 361, 364, 133, 264, 94, 70, 20, 326, 340, 165, 152, 393, 50, 3, 369, 326, 91, 129, 217, 399, 353, 396, 120, 293, 11], 40: [190, 289, 148, 103, 153, 321, 380, 112, 20, 20, 355, 60, 258, 125, 353, 225], 2: [236, 261, 327, 270, 390, 341, 58, 356, 344, 251, 198, 277], 16: [160, 274, 138, 361, 165, 67, 191, 233, 68, 101, 10, 198, 280, 271, 79, 18, 391, 66, 34, 321, 19, 334, 320, 218, 331, 83, 386, 145, 172], 24: [338, 86, 125, 25, 168, 231, 354, 114, 337], 78: [256, 69, 265, 67, 219, 89, 138], 18: [60, 389, 49, 315, 182, 120, 55, 13, 362, 118, 101, 19, 296, 163, 206, 316, 129, 369, 296, 118, 210], 37: [80, 30, 247, 310, 268, 138, 9, 317, 206, 69, 314, 160], 51: [71, 78, 305, 132, 158, 112, 103, 20, 193, 43, 75, 185, 101, 257, 45, 185], 52: [153, 131, 360, 311, 316, 399, 76, 183, 212, 187, 388, 90, 80, 302], 31: [291, 199, 336, 4, 124, 247, 20, 116, 114, 324, 365, 292, 16, 193, 298, 26, 79, 246, 11, 102, 215, 278, 327, 72], 34: [169, 343, 267, 107, 115, 213, 143, 94, 368, 17, 19, 87, 260, 290, 23, 66, 293, 105, 276, 259, 336, 236, 50, 250, 205, 335, 19, 315, 83], 80: [246, 103, 179, 379, 321, 272, 92, 77, 103, 95, 100, 269, 350, 14], 10: [19, 288, 64, 165, 159, 238, 300, 157, 5, 264], 54: [200, 394, 235, 180, 14, 20, 55, 42, 16], 4: [380, 164, 17, 183, 216, 219, 186, 152, 89, 318, 146, 94, 84, 132, 102, 265, 136, 367, 102, 56, 202, 359, 60], 20: [322, 148, 393, 303, 15, 328, 362, 208, 107, 100, 59, 37, 75, 34, 79, 19, 225, 278, 101, 94, 269], 84: [6, 367, 314, 98, 363, 16, 48, 14, 269, 371, 364, 31, 72, 223, 218, 54, 295, 270, 46, 159, 112, 33, 322, 325 ...

# %% [markdown]
# ## Part 2: Assign Threshold
# The following steps assigns a threshold value to each node in the network. The threshold follows a uniform or normal distribution with predefined mean (mu) and standard deviation (sigma).

# %%
import numpy as np
import random

# Defines the parameters to be used
mu = 0.1
sigma = 0.05

# Function to assign thresholds to the individual nodes
def assign_thresholds(hypergraph):
    NV = hypergraph.order()
    Ltre = {}

    for node in hypergraph.nodes():
          # Uniform distribution: #
          #Ltre[node] = np.random.uniform()
          # Normal distrution
          while True:
              threshold = random.gauss(mu, sigma)
              if 0 < threshold < 1:
                  break
          Ltre[node] = threshold

    return Ltre

Ltre = assign_thresholds(H)

print("Threshold List for Nodes: ", Ltre )
# Out:
# Threshold List for Nodes:  {0: 0.0454091472272162, 1: 0.07909523633985291, 2: 0.0663639963773521, 3: 0.08509696967705575, 4: 0.14690778414096606, 5: 0.04984244845808389, 6: 0.1533738430296992, 7: 0.10705760356464368, 8: 0.137279243984147, 9: 0.09044317404131222, 10: 0.14390521645186244, 11: 0.12365615619024677, 12: 0.06736577036202347, 13: 0.1275437566223233, 14: 0.06432466419521496, 15: 0.043471942071409114, 16: 0.061357836601624506, 17: 0.043929346288140304, 18: 0.12726881162195222, 19: 0.10726877669737571, 20: 0.081404366865754, 21: 0.06752913129201762, 22: 0.06327860843890201, 23: 0.11569057581315592, 24: 0.11448018643189124, 25: 0.1636111787219695, 26: 0.10830017803825111, 27: 0.16024207872444735, 28: 0.07005686454657292, 29: 0.017329344397351357, 30: 0.12679333788813824, 31: 0.2625079793572697, 32: 0.004793347672802484, 33: 0.039642891394176476, 34: 0.019579882645721386, 35: 0.08028537370035099, 36: 0.09257346089312127, 37: 0.13699908746681763, 38: 0.06379159777098903, 39: 0.02270882873524721, 40: 0.11792238602992075, 41: 0.1502548684987075, 42: 0.1342608430987538, 43: 0.2105008848172222, 44: 0.12919402262084434, 45: 0.15635964266303765, 46: 0.08347588283031307, 47: 0.1401780503423171, 48: 0.08467521467820116, 49: 0.037702608337621096}

# %%
Ltre2 = assign_thresholds(H2)

print("Threshold List for Nodes: ", Ltre2 )
# Out:
# Threshold List for Nodes:  {0: 0.09264704732212051, 1: 0.06305611432059843, 2: 0.19601068673451752, 3: 0.062241845053473126, 4: 0.166415730929591, 5: 0.056631857878824576, 6: 0.16321881570710622, 7: 0.10081649558979486, 8: 0.0742335891325245, 9: 0.1407328321367928, 10: 0.13702095652292973, 11: 0.08249982647316452, 12: 0.18647355581368927, 13: 0.18421515639482383, 14: 0.11564801170400614, 15: 0.11356524845198511, 16: 0.07792685776217596, 17: 0.12198178964521281, 18: 0.06885531596058707, 19: 0.05003199743081729, 20: 0.1431696179341984, 21: 0.14983924762230275, 22: 0.05256610203625315, 23: 0.16917745170273366, 24: 0.0935067934514116, 25: 0.07476924621965, 26: 0.1477666119534251, 27: 0.1835551884530453, 28: 0.12869349225617152, 29: 0.0571196122828885, 30: 0.06610453779264883, 31: 0.09299264992622694, 32: 0.13373698833913295, 33: 0.1671368567081852, 34: 0.07763074800869448, 35: 0.06947640278541628, 36: 0.1045862739037357, 37: 0.11211950698749706, 38: 0.07932243957893166, 39: 0.047868527060158386, 40: 0.04053845201841114, 41: 0.016070471168189104, 42: 0.13038485188727852, 43: 0.13042947244200492, 44: 0.0916962163168832, 45: 0.10341702969091401, 46: 0.07869628588994977, 47: 0.05094636886795679, 48: 0.07222950357284441, 49: 0.16144491312202736, 50: 0.2215296941884841, 51: 0.19765095914733227, 52: 0.1175677342089268, 53: 0.1325225230071979, 54: 0.1663716190062507, 55: 0.026557070739419417, 56: 0.10974327011513434, 57: 0.052913875376663956, 58: 0.07937409993069787, 59: 0.0987693317323339, 60: 0.1319946472520345, 61: 0.07352539687407057, 62: 0.15775891764120203, 63: 0.0856684572868999, 64: 0.10536950895708445, 65: 0.06676589259109686, 66: 0.045802116395997156, 67: 0.1469818781430301, 68: 0.13412083940599537, 69: 0.20568130043436633, 70: 0.12404775428898661, 71: 0.13574085543180608, 72: 0.11051029484660574, 73: 0.08307609975078534, 74: 0.006440784464234198, 75: 0.07833057405914394, 76: 0.14145432924216253, 77: 0.1335337699223574, 78: 0.1382313269499241, 79: 0.0954701252052927, 80: 0.039437080345291226, 81: 0.07532662620075185, 82: 0.0890016710148883, 83: 0.11730479792114419, 84: 0.14745430569231344, 85: 0.1287180729458558, 86: 0.13878903165085665, 87: 0.12743377535651915, 88: 0.17600209959112975, 89: 0.115447060829215, 90: 0.16108868745933475, 91: 0.05292057892933838, 92: 0.05506514259470342, 93: 0.08288676346586553, 94: 0.09845254641156377, 95: 0.16979931855981906, 96: 0.10366557759859246, 97: 0.07782681560233612, 98: 0.0834965280388881, 99: 0.07011125911633752, 100: 0.1546105763764315, 101: 0.04413513358488899, 102: 0.12951839831273357, 103: 0.031114392859213733, 104: 0.1657369850466504, 105: 0.13483339550714227, 106: 0.03175469490504296, 107: 0.08701535518802735, 108: 0.07745440804336956, 109: 0.15196059374077503, 110: 0.15066871156543732, 111: 0.09067890953490779, 112: 0.1582195464280522, 113: 0.08628536037109859, 114: 0.16333212291044044, 115: 0.1251867063351081, 116: 0.01369160940202914, 117: 0.027012091179244913, 118: 0.1305856659197981, 119: 0.1357196847451409, 120: 0.06409062321416298, 121: 0.1322631715170275, 122: 0.041971261054469314, 123: 0.06524573968628275, 124: 0.08755696646448886, 125: 0.09807672874751035, 126: 0.06286861158193469, 127: 0.07481225764789111, 128: 0.03064837094107352, 129: 0.06369979656313274, 130: 0.07585397860254492, 131: 0.08175194989734239, 132: 0.03790650584611104, 133: 0.20860759483001795, 134: 0.12877010539938302, 135: 0.11621305706668347, 136: 0.025176744152354713, 137: 0.21589737537339926, 138: 0.1837820995689371, 139: 0.09275064742669252, 140: 0.08912068038718587, 141: 0.06507074503024227, 142: 0.12841556560199957, 143: 0.0787149181727726, 144: 0.07577268631288038, 145: 0.05822984718277188, 146: 0.12231542866098397, 147: 0.1567243074283861, 148: 0.09986226760313077, 149: 0.05056238028114393, 150: 0.1123217268362623, 151: 0.11238025070589985, 152: 0.0666646230980879, 153: 0.14695911499734143, 154: 0.01685870854332365, 155: 0.10138532000338228, 156: 0.16969499933131316, 157: 0.13872393255208346, 158: ...

# %% [markdown]
# ## Part 3: Rumor Spreading on Hypergraph
# The follow steps extends the basic rumor spreading model to a hypergraph. An infection or recovery event can only happen if its infected or recovered neighbors reach a pre-assigned threshold.

# %%
def rumor_hyperedge_3(nw, ldeg, mu, lam, alp, n_samp):
    t_max = 10000
    N = nw.order()
    kmax = max(ldeg)
    sigma = 0
    ltre = assign_thresholds(nw)

    t_end = 0
    stifler_fractions = []

    for i_samp in range(1, n_samp+1):
        t = 0
        N_rec = 0

        states = {j: 0 for j in nw.nodes()}

        inf = []
        rec = []
        initial_node = np.random.choice(list(nw.nodes()))
        states[initial_node] = 1
        inf.append(initial_node)
        N_inf = 1
        N_e = nw.degree(initial_node)

        while N_inf != 0:
            total_rate = lam * N_e + 2 * alp * N_e
            tau = -np.log(np.random.uniform(1e-6, 1)) / total_rate
            t += tau

            if t >= t_max:
                break

            #print("Current time:", t)
            #print("Infected nodes:", inf)
            #print("Recovered nodes:", rec)
            #print("N_inf:", N_inf)
            #print("N_e:", N_e)
            #plt.figure()
            #plot_hypergraph(H, states)

            # Determine which event occurs
            event = np.random.uniform()
            p1 = lam / (lam + 2 * alp)
            p2 = (lam + alp )/ (lam + 2 * alp)

            # Determine if accept selected spreader based on degree distribution
            q_deg = np.random.uniform()


            # Infection:
            if event <= p1:
                # Select a spreader individual to spread the rumor
                inf_node = random.choice(inf)
                if q_deg < ldeg[inf_node] / kmax:
                    # Select a random hyper edge containing the infected node
                    infected_hyper_edge = np.random.choice(list(nw.edges()))
                    neighbors = nw[infected_hyper_edge]
                    while inf_node not in neighbors:
                        infected_hyper_edge = np.random.choice(list(nw.edges()))
                        neighbors = nw[infected_hyper_edge]

                    # Check if any neighbor meets the infection threshold
                    for neighbor in neighbors:
                        # Check if the selected neighbor is ignorant
                            if states[neighbor] == 0:
                                #print("Infection event")
                            # Check the threshold
                                count_inf_neighbors = sum(states[node] == 1 for node in nw.neighbors(neighbor))
                                if count_inf_neighbors / len(nw.neighbors(neighbor)) >= ltre[neighbor]:
                                    states[neighbor] = 1  # ignorant neighbor becomes spreader
                                    inf.append(neighbor)
                                    N_inf += 1
                                    #print("successful infection")


            else:  # Recovery
                # Select a spreader individual to recover
                rec_node = np.random.choice(inf)
                if q_deg < ldeg[rec_node] / kmax:
                    # Select a random hyperedge containing the recovered node
                    recovered_hyper_edge = np.random.choice(list(nw.edges()))
                    # Get neighbors list
                    neighbors = nw[recovered_hyper_edge]
                    #print("Recovery event", neighbors)
                    if event <=p2:
                        count_rec_neighbors = sum(states[node] == 2 for node in neighbors)
                        #print("count_rec_neighbors", count_rec_neighbors)
                        if count_rec_neighbors / len(neighbors) >= ltre[rec_node]:
                        #if count_rec_neighbors > 0:
                            # Update spreader to stifler if the selected neighbor is a stifler or spreader
                            states[rec_node] = 2
                            N_inf -= 1
                            inf.remove(rec_node)
                            rec.append(rec_node)
                            N_rec += 1
                            #print("successful recovery")

                    else:
                        count_rec_neighbors = sum(states[node] == 1 for node in neighbors)
                        #print("count_rec_neighbors", count_rec_neighbors)
                        if count_rec_neighbors / len(neighbors) >= ltre[rec_node]:
                        #if count_rec_neighbors > 0:
                            # Update spreader to stifler if the selected neighbor is a stifler or spreader
                            states[rec_node] = 2
                            N_inf -= 1
                            inf.remove(rec_node)
                            rec.append(rec_node)
                            N_rec += 1
                            #print("successful recovery")

                    """
                    else:
                        for neighbor in neighbors:
                        # Check the threshold of infected
                            count_inf_neighbors = 0
                            for node in neighbors:
                                if states[node] == 1:
                                    count_inf_neighbors += 1
                            if count_inf_neighbors / len(neighbors) >= Ltre[rec_node]:
                                # Update spreader to stifler if the selected neighbor is a stifler
                                states[rec_node] = 2
                                N_inf -= 1
                                N_e -= nw.degree(rec_node)
                                inf.remove(rec_node)
                                rec.append(rec_node)
                                N_rec += 1
                    """
            #print("N_inf after event:", N_inf)
            #print("N_e after event:", N_e)


        if N_inf == 0:
              t_end += t
              stifler_frac = N_rec / N
              stifler_fractions.append(stifler_frac)
              print("Sampling result - Lam:", lam, "N_rec:", N_rec, "t_end:", t_end, "stifler_frac:", stifler_frac)

    avg_stifler_frac = sum(stifler_fractions) / len(stifler_fractions)
    t_end_av = t_end/n_samp

    #return nw, states
    return avg_stifler_frac, t_end_av

# %% [markdown]
# The following function generates the hypergraph based on nodes' disease status, where susceptible nodes are yellow, infected nodes are purple, and recovered nodes are green.

# %%
def plot_hypergraph(hypergraph, states):
    pos = nx.spring_layout(hypergraph)
    node_colors = []
    #node_sizes = []
    for node in hypergraph.nodes():
        if states[node] == 1:  # Infected node (purple)
            node_colors.append("purple")
        elif states[node] == 2:  # Recovered node (green)
            node_colors.append("green")
        else:  # Susceptible node (yellow)
            node_colors.append("yellow")
        #node_sizes.append(thresholds[node] * 100)  # Adjust node size based on threshold value

    hnx.drawing.draw(hypergraph, pos, nodes_kwargs={'facecolors': node_colors})

# %%
n_samp = 100
alp = 1

# Set the mu and lambda_values
mu_values = np.arange(0.0, 0.1, 0.1)
lambda_values = np.arange(0.1, 1.0, 0.1)

# Initialize the result array
results = np.zeros((len(mu_values), len(lambda_values)))

# Iterate over mu and lambda values
for i, mu in enumerate(mu_values):
    for j, lam in enumerate(lambda_values):
        rho_R_av, t_end_av = rumor_hyperedge_3(H2, degrees2, mu, lam, alp, n_samp)
        results[i, j] = rho_R_av

import matplotlib.ticker as ticker

# Plot the heat map
fig, ax = plt.subplots(figsize=(8, 6))
heatmap = ax.imshow(results, cmap='YlGnBu', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(lambda_values)))
ax.set_yticks(np.arange(len(mu_values)))

# Format the tick labels with two decimal places using string formatting
lambda_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
mu_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(lambda_formatter)
ax.yaxis.set_major_formatter(mu_formatter)

ax.set_xticklabels(['{:.2f}'.format(val) for val in lambda_values])
ax.set_yticklabels(['{:.2f}'.format(val) for val in mu_values])
plt.xticks(rotation=45)
plt.colorbar(heatmap)

# Set labels and title
ax.set_xlabel('Lambda')
ax.set_ylabel('Mu')
ax.set_title('Average Stifler Density Heatmap')

# Display the heat map
plt.show()
# Out:
# Sampling result - Lam: 0.1 N_rec: 49 t_end: 29.01553437237454 stifler_frac: 0.1225
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 159.61843605677407 stifler_frac: 0.97
# Sampling result - Lam: 0.1 N_rec: 379 t_end: 384.37113436309176 stifler_frac: 0.9475
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 454.1616944713146 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 569.7125002971309 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 945.641058067388 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 951.0345975656518 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 1329.4396988497037 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 1699.1850065033727 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 2092.515515453338 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 2489.4866028296146 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 2903.0964418396393 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 2905.8411432327594 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 2913.39804743404 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 367 t_end: 3268.6015064296266 stifler_frac: 0.9175
# Sampling result - Lam: 0.1 N_rec: 185 t_end: 3476.315665006038 stifler_frac: 0.4625
# Sampling result - Lam: 0.1 N_rec: 381 t_end: 3812.2334147839388 stifler_frac: 0.9525
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 3842.6619900466626 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 366 t_end: 4242.396100865277 stifler_frac: 0.915
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 4618.511444881598 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 356 t_end: 4982.530344420982 stifler_frac: 0.89
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 4982.711955939601 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 5261.875647653612 stifler_frac: 0.97
# Sampling result - Lam: 0.1 N_rec: 386 t_end: 5639.186224876991 stifler_frac: 0.965
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 5643.225187138438 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 386 t_end: 6035.484252019397 stifler_frac: 0.965
# Sampling result - Lam: 0.1 N_rec: 344 t_end: 6385.876964043376 stifler_frac: 0.86
# Sampling result - Lam: 0.1 N_rec: 344 t_end: 6764.384810970385 stifler_frac: 0.86
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 7126.659590666259 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 7129.575689259235 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 379 t_end: 7666.191052217595 stifler_frac: 0.9475
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 8072.563415550721 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 333 t_end: 8377.062737717419 stifler_frac: 0.8325
# Sampling result - Lam: 0.1 N_rec: 328 t_end: 8732.83395725353 stifler_frac: 0.82
# Sampling result - Lam: 0.1 N_rec: 377 t_end: 8911.224836774994 stifler_frac: 0.9425
# Sampling result - Lam: 0.1 N_rec: 390 t_end: 9256.572741886494 stifler_frac: 0.975
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 9633.658392790145 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 359 t_end: 9748.09178654784 stifler_frac: 0.8975
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 10154.502286947194 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 10541.245991913358 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 10953.81856007256 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 11323.412302741352 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 11332.792428680892 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 353 t_end: 11718.798120991518 stifler_frac: 0.8825
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 12097.78222183576 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 12453.04287550039 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 12808.28525006808 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 13192.132496767008 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 362 t_end: 13585.767675666548 stifler_frac: 0.905
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 13970.611905284703 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 13976.727116548978 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 14142.707972624128 stifler_frac: 0.97
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 14737.446994445389 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 14737.73951257436 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 15150.142604157507 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 382 t_end: 15524.525004705085 stifler_frac: 0.955
# Sampling result - Lam: 0.1 N_rec: 386 t_end: 15882.729629597352 stifler_frac: 0.965
# Sampling result - Lam: 0.1 N_rec: 372 t_end: 16231.12295653146 stifler_frac: 0.93
# Sampling result - Lam: 0.1 N_rec: 351 t_end: 16567.359590364096 stifler_frac: 0.8775
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 16957.141035525874 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 374 t_end: 17336.217008318858 stifler_frac: 0.935
# Sampling result - Lam: 0.1 N_rec: 376 t_end: 17725.52013121027 stifler_frac: 0.94
# Sampling result - Lam: 0.1 N_rec: 377 t_end: 18082.391391979785 stifler_frac: 0.9425
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 18496.446350062855 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 18528.756649638897 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 383 t_end: 18915.084789704313 stifler_frac: 0.9575
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 19273.44503468777 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 19659.678370230242 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 19660.50722813171 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 20050.347563864845 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 20398.647567186 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 390 t_end: 20631.661708199557 stifler_frac: 0.975
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 20747.509148623692 stifler_frac: 0.97
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 21126.89843734044 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 378 t_end: 21497.554569234064 stifler_frac: 0.945
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 21879.3510047677 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 386 t_end: 22259.12800787524 stifler_frac: 0.965
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 22269.929333226806 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 22889.3229115553 stifler_frac: 0.97
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 23298.39549432249 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 23732.346669801253 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 24316.866028434753 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 24577.94596488416 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 24935.5156364808 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 390 t_end: 25304.06914055257 stifler_frac: 0.975
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 25307.028866924265 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 25311.037446053488 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 378 t_end: 25655.982950411184 stifler_frac: 0.945
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 26055.914616080896 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 374 t_end: 26446.471474168437 stifler_frac: 0.935
# Sampling result - Lam: 0.1 N_rec: 349 t_end: 26551.93090951353 stifler_frac: 0.8725
# Sampling result - Lam: 0.1 N_rec: 390 t_end: 26637.934130522426 stifler_frac: 0.975
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 26638.587180483264 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 27002.2852248063 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 27403.600631284608 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 27769.011754272437 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 28138.389086793228 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 28530.259270676048 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 383 t_end: 28901.13681052783 stifler_frac: 0.9575
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 29270.413273493425 stifler_frac: 0.9725
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 396.2174947770404 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 582.4376829935135 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 969.4231253722842 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 1401.7804398908656 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 2009.2112991570157 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 2299.6570292033334 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 2674.225488432931 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 395 t_end: 3064.2736474828985 stifler_frac: 0.9875
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 3409.8508652142423 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 3789.0610244367667 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 4197.864786612776 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 4612.706102471243 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 5009.521013841762 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 394 t_end: 5409.178858063371 stifler_frac: 0.985
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 5522.153134820131 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 5869.845019984648 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 6206.987443997352 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 6597.4986143762135 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 393 t_end: 6959.022688133679 stifler_frac: 0.9825
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 7353.221410444399 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 391 t_end: 7740.731894285676 stifler_frac: 0.9775
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 7894.950051118067 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 8179.3359015224905 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 8614.032377546726 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 8738.970321898754 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 9122.507963699773 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 9493.248926145696 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 9856.595268423616 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 10270.000362511777 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 10648.349939945212 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 11046.98893888976 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 11434.28018312814 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 11799.68276158405 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 12159.785161687878 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 394 t_end: 12518.831025109264 stifler_frac: 0.985
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 12895.20272406337 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 13264.423073326552 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 395 t_end: 13614.20643773874 stifler_frac: 0.9875
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 14014.800052536251 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 14390.67934897609 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 14667.521393982142 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 15073.374905374474 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 15444.640527986947 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 15822.338216014072 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 16005.008223038101 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 16301.63042758536 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 16646.819966332565 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 17055.181118604734 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 17057.660549146975 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 17058.401017858912 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 17064.56095399962 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 17526.17435643968 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 17903.661414798502 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 18294.767321649786 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 18642.876494142 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 19047.498596716003 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 19592.18462896325 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 20005.477631284728 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 387 t_end: 20364.22524841225 stifler_frac: 0.9675
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 20787.361340214477 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 21192.69045337373 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 21373.816956669303 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 387 t_end: 21713.861348514718 stifler_frac: 0.9675
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 22121.19568414511 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 22498.676630835733 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 22896.6347579227 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 23282.84562183462 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 23682.282519632823 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 24059.22688455376 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 24430.76868086922 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 24818.71271780707 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 25181.196012046734 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 25202.398649676583 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 25202.740637599272 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 25634.227880390823 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 26013.664905701604 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 26388.16364014926 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 26388.363131332007 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 26515.536099904795 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 26877.123743628777 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 390 t_end: 27292.069919987363 stifler_frac: 0.975
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 27663.786187795362 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 394 t_end: 28032.724601277623 stifler_frac: 0.985
# Sampling result - Lam: 0.2 N_rec: 393 t_end: 28404.443936779004 stifler_frac: 0.9825
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 28561.80948640354 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 28854.359232861756 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 29222.45403935515 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 388 t_end: 29592.955286586614 stifler_frac: 0.97
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 29594.086565088473 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 29988.665627584378 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 30361.528904311417 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 30729.55872608882 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 31098.20427963486 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 31448.8794487501 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 396 t_end: 31850.37805789128 stifler_frac: 0.99
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 32268.15270741578 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 32689.023542007988 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 33107.28728239473 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 33459.18344672578 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 34008.728968359894 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 388.6705351575952 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 465.3261098067316 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 874.7374825449458 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1282.7824076292509 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1654.3796745066563 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2039.7058828159898 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 2325.6224217315053 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 2686.695559193177 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3093.9943990649244 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 3314.6394495143186 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3625.3687400261383 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 4011.3775462059657 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 4394.47092037281 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 397 t_end: 4746.697065170119 stifler_frac: 0.9925
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5142.091065234533 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 5496.181020140017 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5855.747479398301 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 6139.96864406008 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 6502.171763192509 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 6879.449340079504 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 7250.33134733756 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 7657.381720382253 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 8051.508050850237 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 8407.757726863047 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 8776.776784520933 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 8782.448139988974 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 9191.05039391461 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 9568.381770286938 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 9936.348031168134 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 10219.933387638206 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 10636.542161939497 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 11034.101248577657 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 11444.101282832633 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 11588.96349468825 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 11956.373343242738 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 12313.328842303576 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 12706.342562343863 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 397 t_end: 13073.170927192163 stifler_frac: 0.9925
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 13075.335193632916 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 13378.831443656141 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 13382.226888983112 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 13760.577748286483 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 397 t_end: 14127.574400273337 stifler_frac: 0.9925
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 14497.00572727421 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 14900.769216290142 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 15264.86470633416 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 15627.215535465384 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 16030.237419103405 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 16432.48923589782 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 16805.028169796136 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 17175.993034496976 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 17552.96260394652 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 397 t_end: 17918.35762843317 stifler_frac: 0.9925
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 18282.56571465143 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 18681.524236710087 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 19033.167183808488 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 19434.889513240163 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 19816.00532736636 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 395 t_end: 20062.64430699605 stifler_frac: 0.9875
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 20386.008642008015 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 20598.77171503123 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 20946.538464006906 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 21295.639583160635 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 21709.257188231844 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 22076.091673253573 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 22452.83392721536 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 22839.431786982208 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 22839.515111922294 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 22972.27659377437 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 23361.654564679844 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 23746.90639445647 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 24122.025109658443 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 24406.904586468143 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 24802.67382918252 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 25174.08097530483 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 25574.85964563617 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 25989.452640644573 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 26352.620551782693 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 395 t_end: 26690.768378133198 stifler_frac: 0.9875
# Sampling result - Lam: 0.30000000000000004 N_rec: 397 t_end: 27084.25523516997 stifler_frac: 0.9925
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 27085.38607971562 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 27097.82989307265 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 27504.20168391448 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 27897.42899318567 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 28072.46771207745 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 28421.72095163426 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 28826.418924031415 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 29199.391458539492 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 29535.568171787392 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 29894.58823604014 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 30460.8395927494 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 30544.030752941824 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 30933.145536541815 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 31302.943221270532 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 31673.174306702334 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 32035.91993323768 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 32391.957481446305 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 32771.89049422473 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 33145.72303393823 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 33376.838528313216 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 293.4353725852886 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 658.2907565505793 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1038.1631239722158 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1302.8557768517571 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 398 t_end: 1666.0840333738197 stifler_frac: 0.995
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 2116.4085494812675 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2391.4405343472195 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2787.9352306123474 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3159.616607862818 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3521.4674588975663 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3908.145385787073 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 4507.062006562781 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 4788.412818507737 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 5183.556614715502 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5546.626350179051 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5924.220253176771 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 6305.431092697339 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 6307.992804934079 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 6859.008246398123 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 7030.008356003857 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 7178.820008950693 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 7564.827656724995 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 7923.378319540438 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 8360.191128346682 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 8734.590302083374 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 9116.649755489785 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 9492.449613253146 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 9570.074820319778 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 9951.138569129756 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 10352.359116567703 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 10690.092393255805 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 11060.766322261483 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 11431.175886152345 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 11433.618042531023 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 11831.043748820237 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 12197.003586946079 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 12587.208484231209 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 12971.994584802433 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 13365.582494239796 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 13770.214764945707 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 14197.09710742943 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 14604.161190205352 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 398 t_end: 14967.67677589543 stifler_frac: 0.995
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 15344.93165794886 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 15750.024019832 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 15924.48233836789 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 16003.283201360873 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 16372.252973751802 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 16754.045357755986 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 17116.989202399353 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 17521.261509163312 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 17674.866777926476 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 17971.48671147033 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 18356.03666829714 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 18734.02031647641 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 398 t_end: 19132.972396015655 stifler_frac: 0.995
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 19540.0285505346 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 19763.72456929289 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 20144.86281251661 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 20505.282659028428 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 20883.467281524445 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 21247.495317644723 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 21620.890118070987 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 21621.08799623637 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 21982.88256719658 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 22339.03210948979 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 22704.84088459792 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 23093.57857518692 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 23271.537304820136 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 23654.074350482293 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 24049.90459505999 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 24467.985725977604 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 24771.227186815115 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 25134.721280108424 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 25526.219869097855 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 398 t_end: 25926.603164666947 stifler_frac: 0.995
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 26318.110662552175 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 26717.972695954188 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 27104.393940918257 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 27520.14578245743 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 27887.29974927561 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 28268.82623172176 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 28636.0044657932 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 29015.275205856884 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 29403.873758315436 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 29789.800809304612 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 30195.798143299053 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 30595.857911678875 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 30973.346477323394 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 31313.77451960616 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 31667.479204842006 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 32041.84308692397 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 32453.670453964667 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 32827.55710727168 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 33239.19895108232 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 33579.37122851383 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 34108.77750093009 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 34466.477301955034 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 34816.59013461444 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 35204.30136163212 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 356.46762596695135 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 728.7962315776529 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 1090.531846959398 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 1459.5504207852628 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 1879.8774370855622 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 2213.6503484372624 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 2584.4316121083284 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 2584.5765912732422 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 2947.0712201733295 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 3223.419487483682 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 3617.7491522467826 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 4028.530940299988 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 4408.900239762501 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 4772.749407851012 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 5176.010804898228 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 5551.151431109422 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 5889.160310197703 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 6254.421573415151 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 6667.648309079157 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 7023.022509740425 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 7414.266513802206 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 7776.770478926177 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 8159.573376216686 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 8554.936932056617 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 8915.48156210062 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 9258.419721139191 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 9615.89447777987 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 9881.169127249892 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 10220.434869712906 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 10609.188014095931 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 11023.11080831896 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 11414.07339305555 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 11793.882061602542 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 12143.214870057183 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 12524.611787177842 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 12877.984595025673 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 13175.688019851335 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 13594.103517401923 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 13945.281373517948 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 14156.771191461237 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 14548.294598291062 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 14926.108838180968 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 15278.511473876222 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 15844.99570180499 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 16207.356418300827 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 16375.840850025743 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 16744.143000820808 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 17124.87848858775 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 17512.087042127067 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 17893.135802826633 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 18258.291300417863 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 18643.06766072541 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 18999.1207270256 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 19348.767469071718 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 19710.720018594293 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 20055.906569315473 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 20057.619862224055 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 20402.152041893754 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 20785.31601565508 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 21167.066069006676 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 21526.729415300615 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 21715.86639568017 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 22091.211958290467 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 22190.222510334956 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 22573.331095574333 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 22932.902555406756 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 23076.018891449705 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 23473.128552614147 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 23844.434769987463 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 24213.68135482447 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 24339.203702263232 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 24725.978518765038 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 25098.22515930551 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 25470.775357534436 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 25884.65896728278 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 26270.823331060164 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 26607.82529944411 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 27002.451163108017 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 27406.116851032602 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 27591.717219331622 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 27977.810900494867 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 28344.147766968614 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 28714.83874708321 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 28719.520196690766 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 29069.274055829792 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 29454.885888849156 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 29812.929616493144 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 30033.372650152098 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 30384.58407872629 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 30764.4807530058 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 31143.5937379576 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 31516.32784660353 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 31902.0339444877 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 32278.044961000232 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 399 t_end: 32662.84314467421 stifler_frac: 0.9975
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 33046.55963309865 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 33427.82566743223 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 33794.29066570442 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 34161.99103449225 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 34527.35133231543 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 380.4246273835255 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 555.8940074894184 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 917.2827599176534 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 1275.3078122332142 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 1653.7466785998317 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 2031.5673895920147 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 2382.901287397766 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 2757.9064730410523 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 3153.2889294168367 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 3413.549849779315 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 3756.5264684986128 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 4191.667354983735 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 1 t_end: 4193.255259536345 stifler_frac: 0.0025
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 4567.86657754134 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 4933.40801448638 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 5304.673954006124 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 5659.361531130009 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 6022.443992889532 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 6130.386730983665 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 1 t_end: 6139.31471083139 stifler_frac: 0.0025
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 6749.2243069042615 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 6960.902305268193 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 7335.907479373045 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 7699.933343054918 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 8266.120767265382 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 8660.521393448176 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 9012.236608086463 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 9411.822664880767 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 9790.620279788067 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 10125.896660670942 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 10499.151767166028 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 11086.272204817817 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 11443.678360807326 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 11571.26133737181 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 11952.749922158322 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 12333.730081826749 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 12635.818143668988 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 12716.893090845826 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 13135.304284601816 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 13746.638009117944 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 14132.230297373782 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 14511.187493619002 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 14849.990735736186 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 15200.543486539236 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 15575.254343495688 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 15653.018328199152 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 15784.802480618877 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 16160.394647139497 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 16522.025832296953 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 16919.57819758961 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 17266.56491098949 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 17634.7923066965 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 17910.249766258665 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 18294.621611517185 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 18490.35464253687 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 18860.248432531942 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 19236.643369620062 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 399 t_end: 19532.291964785327 stifler_frac: 0.9975
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 19917.321745537945 stifler_frac: 1.0
# ...
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 2218.537595092954 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 2569.8747735952034 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 2934.857836908133 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 3332.548110628182 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 3606.8037202483074 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 4001.301179658547 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 4365.093096008473 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 4729.629949722727 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 5094.629777229212 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 5457.145279399071 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 5846.9323999164035 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 6209.286880449725 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 6209.415148473404 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 6576.072745210585 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 6946.248369806502 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 7314.7464357443405 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 7698.217023895681 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 8060.461992614515 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 8430.032943103199 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 8972.435022017797 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 9367.926158274462 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 9736.441955957473 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 9736.452838765075 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 9924.780786600377 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 10269.200857909951 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 10650.473418978721 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 11014.912987794989 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 11424.646792296568 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 11747.452087510943 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 12157.039971439195 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 12551.98628213226 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 12553.511427481348 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 12922.809263591836 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 13287.525537585163 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 13649.295984858836 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 13883.882603897006 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 14240.23133052884 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 14662.039856082016 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 14662.274979808182 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 14664.883831191892 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 15054.66682539692 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 15425.691637725271 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 15775.040244397973 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 16143.869073152697 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 16541.457561449024 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 16887.631387489353 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 16887.813618473574 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 17259.605937787645 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 17558.802530425222 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 17936.77693758123 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 18304.95320912473 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 18483.696883826266 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 18848.135519301843 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 19206.54712495691 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 19572.07193988154 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 19572.192963243782 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 19952.99361029948 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 20328.23031287205 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 20721.503289923716 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 21069.379033702917 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 21409.437788382424 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 21766.492051001638 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 22120.899915832237 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 22502.57488880521 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 22866.440225006314 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 23264.204195448052 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 23603.92243890383 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 23973.330900021887 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 24376.522418297634 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 24764.08876411811 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 25145.66130445011 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 25299.007565064363 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 25650.562649177267 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 25842.808213541764 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 26235.121783654693 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 26593.010014925676 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 26979.717764550136 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 27351.664441749155 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 27920.682279806162 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 28418.08591882368 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 28595.721643501747 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 28991.37876821228 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 29109.038766904876 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 29501.050352530085 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 29847.19944594356 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 30209.786759935145 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 30560.894384334646 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 30686.72916879827 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 31060.208418325165 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 398 t_end: 31432.177219325036 stifler_frac: 0.995
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 31792.17682188752 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 32166.205769816766 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 32575.59688769619 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 33118.771667490284 stifler_frac: 0.9975
# Sampling result - Lam: 0.8 N_rec: 399 t_end: 33489.9532089318 stifler_frac: 0.9975
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 171.01166719085842 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 521.6946559595146 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 906.0992692900122 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 1300.1516268832063 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 1687.9343470184087 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 2062.8458533615326 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 2630.4530650203865 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 3025.6948210774153 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 3404.346142337676 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 3792.9318558633113 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 4191.96696781876 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 4485.784828948805 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 4857.979016404105 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 5138.635135786737 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 399 t_end: 5561.57627973715 stifler_frac: 0.9975
# Sampling result - Lam: 0.9 N_rec: 399 t_end: 5928.842425936606 stifler_frac: 0.9975
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 6316.848679686858 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 6713.305078472274 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 7051.932539777029 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 7403.588266640318 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 7750.429352706904 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 8188.003187425464 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 8188.085051578753 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 8559.921982003683 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 8928.018495254813 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 9284.934346191063 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 9647.859565253933 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 10013.606088820434 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 10375.868002738012 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 10801.351096106304 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 399 t_end: 11155.273035226994 stifler_frac: 0.9975
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 11488.783936963368 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 11834.86847719013 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 12187.81052263352 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 12558.8961894576 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 12917.686542797128 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 13267.536064438822 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 13273.857637636378 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 13647.277619847662 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 14011.117757355498 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 14382.84207964274 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 14759.454146159329 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 14986.044768707965 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 15260.358717542184 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 15785.553772953132 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 16415.694612802396 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 16766.946854731897 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 17132.778164112016 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 17484.02034388059 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 17878.45729799881 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 18265.09345687876 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 18672.34534409888 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 19062.228579908628 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 19450.18038870973 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 19760.738845429532 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 19971.85230217856 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 20360.6848517606 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 20747.90953046438 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 20748.240822679938 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 21104.847780478874 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 21473.41397069322 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 21856.643546830153 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 22251.29198882253 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 22624.63973216894 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 22999.77355485974 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 23357.767435630056 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 23764.124174220986 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 24117.36011960942 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 24500.359492119293 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 24904.05924330189 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 25298.960687522755 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 25838.06451277296 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 26193.489660530104 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 26539.540859253935 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 26919.50797579912 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 27277.45982703006 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 27645.791863067712 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 399 t_end: 27753.389188817808 stifler_frac: 0.9975
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 28122.740599186556 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 28423.194078167002 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 28553.425430290376 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 28924.62077475576 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 29309.235900376065 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 29704.546843906126 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 30295.482737649763 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 30701.69791931944 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 31074.5658997614 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 31439.547843850112 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 31811.2265913187 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 32195.445952578466 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 32576.4119993776 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 32963.39485430017 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 33078.39039417892 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 33483.72032615671 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 33889.05891612429 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 34232.97995024479 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 34314.637225078826 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 34678.0675594681 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 35052.01776257978 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 35414.57377195895 stifler_frac: 1.0
