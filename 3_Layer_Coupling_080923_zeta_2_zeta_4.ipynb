_rate = lam * N_e_i + 2 * alp * N_e_i + beta_NN * N_e_e + mu * N_infected + zeta_1 * N_gossip + zeta_2 * (N-N_gossip) + zeta_3 * (N-N_protected) + zeta_4 * N_protected
          tau = -np.log(np.random.uniform(1e-6, 1)) / total_rate
          t += tau

          if t >= t_max:
                break

          # Determine which event occurs
          event = np.random.uniform()
          p1 = (lam * N_e_i) / total_rate     # rumor spreading
          p2 = (lam * N_e_i + alp * N_e_i) / total_rate  # rumor stifling (by meeting stifling neighbor threshold)
          p3 = (lam * N_e_i + 2 * alp * N_e_i) / total_rate  # rumor stifling (by meeting gossip neighbor threshold)

          p4 = (lam * N_e_i + 2 * alp * N_e_i + beta_NN * N_e_e) / total_rate  # disease propagation
          p5 = (lam * N_e_i + 2 * alp * N_e_i + beta_NN * N_e_e + mu * N_infected) / total_rate  # disease recovery

          p6 = (lam * N_e_i + 2 * alp * N_e_i + beta_NN * N_e_e + mu * N_infected + zeta_1 * N_gossip) / total_rate # change to not adopting protection by information
          p7 = (lam * N_e_i + 2 * alp * N_e_i + beta_NN * N_e_e + mu * N_infected + zeta_1 * N_gossip + zeta_2 * (N-N_gossip)) / total_rate # change to adopting protection by information
          p8 = (lam * N_e_i + 2 * alp * N_e_i + beta_NN * N_e_e + mu * N_infected + zeta_1 * N_gossip + zeta_2 * (N-N_gossip) + zeta_3 * (N-N_protected)) / total_rate # change to not adopting protection by neighborhood behavior
          # > p8 # change to adopting protection by neighborhood behavior
          #print(p1, p2, p3, p4, p5, p6, p7, p8)

          # Determine if accept selected individual based on degree distribution
          q_deg_i = np.random.uniform()
          q_deg_c = np.random.uniform()
          q_deg_e = np.random.uniform()

          # Case 1: Rumor spreading
          if event < p1:
                gossip_node = random.choice(gossip)
                if q_deg_i < inw.degree(gossip_node) / kmax_i:
                    rumor_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[rumor_hyper_edge]
                    """
                    while gossip_node not in neighbors:
                        rumor_hyper_edge = np.random.choice(list(inw.edges()))
                        neighbors = inw[rumor_hyper_edge]
                    """
                    MAX_ITERATIONS = 20 # Set a reasonable limit based on your specific case
                    iterations = 0
                    while gossip_node not in neighbors:
                        if iterations > MAX_ITERATIONS:
                           break
                        rumor_hyper_edge = np.random.choice(list(inw.edges()))
                        neighbors = inw[rumor_hyper_edge]
                        iterations += 1

                    for neighbor in neighbors:
                            if info_states[neighbor] == "U":
                                count_gossip_neighbors = sum(1 for node in inw.neighbors(neighbor) if info_states[node] == "G")
                                if count_gossip_neighbors / len(inw.neighbors(neighbor)) >= ltre[neighbor]:
                                    info_states[neighbor] = "G"  # uninformed neighbor becomes gossip spreader
                                    gossip.append(neighbor)
                                    N_gossip += 1



          # Case 2: Rumor stifling (by meeting stifling neighbor threshold)
          elif event < p2:
            #if N_gossip > 0:
                stifler_node = np.random.choice(gossip)
                if q_deg_i < inw.degree(stifler_node)  / kmax_i:
                    stifler_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[stifler_hyper_edge]
                    count_stifler_neighbors = sum(1 for node in inw.neighbors(stifler_node) if info_states[node] == "C")
                    if count_stifler_neighbors / len(neighbors) >= ltre[stifler_node]:
                            info_states[stifler_node] = "C"
                            N_gossip -= 1
                            gossip.remove(stifler_node)
                            corrected.append(stifler_node)
                            N_corrected += 1

          # Case 3: Rumor stifling (by meeting gossip neighbor threshold)
          elif event < p3:
            #if N_gossip > 0:
                stifler_node = np.random.choice(gossip)
                if q_deg_i < inw.degree(stifler_node) / kmax_i:
                    stifler_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[stifler_hyper_edge]
                    count_gossip_neighbors = sum(1 for node in inw.neighbors(stifler_node) if info_states[node] == "G")
                    if count_gossip_neighbors / len(neighbors) >= ltre[stifler_node]:
                            info_states[stifler_node] = "C"
                            N_gossip -= 1
                            gossip.remove(stifler_node)
                            corrected.append(stifler_node)
                            N_corrected += 1

          # Case 4: Disease propagation
          elif event < p4:
            if N_infected > 0:
              infected_node = np.random.choice(infected)
              infected_protected = lprot[infected_node]
              neighbors = list(enw.neighbors(infected_node))
              susceptible_neighbors = [n for n in neighbors if disease_states[n] == "S"]

              if len(susceptible_neighbors) > 0:
                  neighbor = np.random.choice(susceptible_neighbors)
                  neighbor_protected = lprot[neighbor]

                  # Determine the appropriate transmission rate based on protection status
                  if neighbor_protected == "P" and infected_protected == "P":
                            transmission_rate = beta_PP/beta_NN
                  elif neighbor_protected == "N" and infected_protected == "P":
                            transmission_rate = beta_NP/beta_NN
                  elif neighbor_protected == "P" and infected_protected == "N":
                            transmission_rate = beta_PN/beta_NN
                  else:
                            transmission_rate = beta_NN/beta_NN

                  if np.random.uniform() < transmission_rate:
                      disease_states[neighbor] = "I"
                      infected.append(neighbor)
                      N_infected += 1
                      N_e_e += enw.degree(neighbor)

          # Case 5: Disease recovery
          elif event < p5:
            if N_infected > 0:
                recovered_node = np.random.choice(infected)
                if q_deg_e < ldeg_e[recovered_node]/kmax_e:
                    disease_states[recovered_node] = "R"
                    infected.remove(recovered_node)
                    recovered.append(recovered_node)
                    N_infected -= 1
                    N_recovered += 1
                    N_e_e -= enw.degree(recovered_node)

          # Case 6: # Change to not adopting protection based on information layer
          # rate = zeta_1 * n_G / k_info
          # n_G is the total spreader neighbors on the information layer,
          # while k_info is the total neighbor count on the information layer
          elif event < p6:
            if len(protected) > 0:
              node_to_not_protect = np.random.choice(protected)
              n_G = sum(1 for node in filter(lambda x: info_states[x] == "G", inw.neighbors(node_to_not_protect)))
              k_info = len(inw.neighbors(node_to_not_protect))
              if np.random.uniform() < zeta_1 * n_G / k_info:
                    lprot[node_to_not_protect] = "N"
                    protected.remove(node_to_not_protect)
                    not_protected.append(node_to_not_protect)
                    N_protected -= 1

          # Case 7: Change to adopting protection based on information layer
          # rate = zeta_2 * (1 - n_G / k_info)
          elif event < p7:
            if len(not_protected) > 0:
                node_to_protect = np.random.choice(not_protected)
                n_G = sum(1 for node in filter(lambda x: info_states[x] == "G", inw.neighbors(node_to_protect)))
                k_info = len(inw.neighbors(node_to_protect))
                if np.random.uniform() < zeta_2 * (1 - n_G / k_info):
                        lprot[node_to_protect] = "P"
                        not_protected.remove(node_to_protect)
                        protected.append(node_to_protect)
                        N_protected += 1


          # Case 8: # Change to not adopting protection based on neighborhood behavior in cognition layer
          # rate = zeta_3 * (1 - n_P / k_cog)
          # n_P is the total protected neighbors on the cognition layer,
          # while k_cog is the total neighbor count on the cognition layer
          elif event < p8:
            if len(protected) > 0:
                node_to_not_protect = np.random.choice(protected)
                n_P = sum(1 for node in filter(lambda x: lprot[x] == "P", cnw.neighbors(node_to_not_protect)))
                k_cog = len(cnw.neighbors(node_to_not_protect))
                if np.random.uniform() < zeta_3 * (1 - n_P / k_cog):
                        lprot[node_to_not_protect] = "N"
                        protected.remove(node_to_not_protect)
                        not_protected.append(node_to_not_protect)
                        N_protected -= 1


          # Case 9: # Change to adopting protection based on neighborhood behavior in cognition layer
          # rate = zeta_4 * n_P / k_cog
          else:
            if len(not_protected) > 0:
                node_to_protect = np.random.choice(not_protected)
                n_P = sum(1 for node in filter(lambda x: lprot[x] == "P", cnw.neighbors(node_to_protect)))
                k_cog = len(cnw.neighbors(node_to_protect))
                if np.random.uniform() < zeta_4 * n_P / k_cog:
                        lprot[node_to_protect] = "P"
                        not_protected.remove(node_to_protect)
                        protected.append(node_to_protect)
                        N_protected += 1
      #print("N_infected", N_infected, "N_gossip", N_gossip)
      if N_infected == 0:
          corrected_frac = N_corrected / N
          protected_frac = N_protected / N
          recovered_frac = N_recovered / N
          rho_C.append(corrected_frac)
          rho_P.append(protected_frac)
          rho_R.append(recovered_frac)
          #print("corrected_frac", corrected_frac, "recovered_frac", recovered_frac)

  avg_rho_C = sum(rho_C) / len(rho_C)
  avg_rho_P = sum(rho_P) / len(rho_P)
  avg_rho_R = sum(rho_R) / len(rho_R)

  return avg_rho_C, avg_rho_P, avg_rho_R

# %%
n = 400  # Number of nodes

# Information Layer
gamma_i = 2.5  # Power-law exponent
kmin_i = 3  # Minimum degree
num_hyper_edges_i = 100  # Desired number of hyper edges
ldeg_i, hyperedge_dict_i = build_hypergraph(n, gamma_i, kmin_i, num_hyper_edges_i)
inw = hnx.Hypergraph(hyperedge_dict_i)
ltre = assign_thresholds(inw, 0.05, 0.03)

# Cognition Layer
gamma_c = 3.0  # Power-law exponent
kmin_c = 3  # Minimum degree
num_hyper_edges_c = 100  # Desired number of hyper edges
ldeg_c, hyperedge_dict_c = build_hypergraph(n, gamma_c, kmin_c, num_hyper_edges_c)
cnw = hnx.Hypergraph(hyperedge_dict_c)
frac_prot = 0.1
lprot = assign_protection(cnw, frac_prot)

# Epidemic Layer
gamma_e = 4.0
kmin_e = 3
ldeg_e = generate_degree_sequence(n, gamma_e, kmin_e)
print("Degree Sequence: ", ldeg_e)
enw = nx.configuration_model(ldeg_e)
# Out:
# Degree Sequence:  [3, 11, 3, 4, 3, 4, 6, 6, 3, 4, 7, 3, 3, 3, 9, 3, 7, 6, 14, 3, 3, 3, 3, 4, 9, 3, 4, 8, 7, 4, 4, 3, 12, 4, 3, 3, 4, 5, 3, 3, 6, 3, 3, 4, 4, 3, 3, 3, 4, 3, 4, 3, 3, 9, 4, 3, 6, 4, 3, 3, 4, 5, 4, 15, 3, 3, 3, 4, 3, 3, 4, 5, 5, 3, 3, 7, 3, 3, 4, 7, 9, 4, 8, 7, 3, 5, 8, 5, 6, 4, 4, 5, 4, 3, 3, 9, 3, 3, 8, 4, 4, 4, 5, 17, 3, 4, 3, 5, 6, 3, 3, 3, 3, 3, 4, 3, 7, 4, 3, 3, 3, 3, 8, 6, 3, 3, 3, 6, 5, 3, 5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  
 224: 'N', 225: 'N', 226: 'N', 227: 'N', 228: 'N', 229: 'N', 230: 'N', 231: 'N', 232: 'N', 233: 'N', 234: 'N', 235: 'N', 236: 'N', 237: 'N', 238: 'N', 239: 'N', 240: 'N', 241: 'N', 242: 'N', 243: 'N', 244: 'N', 245: 'N', 246: 'N', 247: 'N', 248: 'N', 249: 'N', 250: 'N', 251: 'N', 252: 'N', 253: 'N', 254: 'N', 255: 'N', 256: 'N', 257: 'N', 258: 'N', 259: 'N', 260: 'N', 261: 'N', 262: 'N', 263: 'N', 264: 'N', 265: 'N', 266: 'N', 267: 'N', 268: 'N', 269: 'N', 270: 'N', 271: 'N', 272: 'N', 273: 'N', 274: 'N', 275: 'N', 276: 'N', 277: 'N', 278: 'N', 279: 'N', 280: 'N', 281: 'N', 282: 'N', 283: 'P', 284: 'N', 285: 'N', 286: 'N', 287: 'N', 288: 'N', 289: 'N', 290: 'P', 291: 'P', 292: 'N', 293: 'N', 294: 'P', 295: 'N', 296: 'N', 297: 'N', 298: 'N', 299: 'N', 300: 'N', 301: 'N', 302: 'N', 303: 'N', 304: 'N', 305: 'N', 306: 'N', 307: 'N', 308: 'N', 309: 'N', 310: 'N', 311: 'N', 312: 'N', 313: 'N', 314: 'N', 315: 'N', 316: 'N', 317: 'N', 318: 'N', 319: 'N', 320: 'N', 321: 'N', 322: 'N', 323: 'N', 324: 'N', 325: 'N', 326: 'P', 327: 'N', 328: 'P', 329: 'P', 330: 'N', 331: 'N', 332: 'N', 333: 'N', 334: 'N', 335: 'N', 336: 'N', 337: 'N', 338: 'N', 339: 'N', 340: 'N', 341: 'N', 342: 'P', 343: 'N', 344: 'P', 345: 'N', 346: 'N', 347: 'N', 348: 'N', 349: 'N', 350: 'P', 351: 'P', 352: 'P', 353: 'N', 354: 'N', 355: 'N', 356: 'N', 357: 'N', 358: 'N', 359: 'N', 360: 'N', 361: 'N', 362: 'N', 363: 'N', 364: 'N', 365: 'N', 366: 'N', 367: 'N', 368: 'N', 369: 'N', 370: 'N', 371: 'N', 372: 'N', 373: 'N', 374: 'N', 375: 'N', 376: 'N', 377: 'P', 378: 'N', 379: 'N', 380: 'N', 381: 'N', 382: 'N', 383: 'N', 384: 'N', 385: 'N', 386: 'N', 387: 'N', 388: 'N', 389: 'N', 390: 'N', 391: 'N', 392: 'N', 393: 'N', 394: 'N', 395: 'N', 396: 'N', 397: 'N', 398: 'N', 399: 'N'}
# Degree Sequence:  [3, 4, 3, 3, 5, 3, 4, 3, 5, 3, 5, 3, 3, 3, 3, 3, 4, 3, 5, 3, 4, 3, 3, 4, 5, 3, 3, 3, 3, 3, 3, 3, 5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
lam = 0.1
alp = 1
zeta_1 = 0.1
zeta_3 = 0.1
beta_PP = 0.025
beta_NP = 0.05
beta_PN = 0.2
beta_NN = 0.4
mu = 1
n_sample = 50

# Set the SN-IP and SP-IN disease spreading rates
zeta_2_values = np.arange(0.05, 0.3, 0.05)
zeta_4_values = np.arange(0.05, 0.3, 0.05)

# Initialize the result array
results_rho_C = np.zeros((len(zeta_2_values), len(zeta_4_values)))
results_rho_R = np.zeros((len(zeta_2_values), len(zeta_4_values)))

# Iterate over mu and lambda values
for i, zeta_2 in enumerate(zeta_2_values):
    for j, zeta_4 in enumerate(zeta_4_values):
        avg_rho_C, avg_rho_P, avg_rho_R = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
        results_rho_C[i, j] = avg_rho_C
        results_rho_R[i, j] = avg_rho_R
        print("zeta_2:", zeta_2, "zeta_4:", zeta_4, "rho_C:", avg_rho_C, "rho_R:", avg_rho_R)
# Out:
# zeta_2: 0.05 zeta_4: 0.05 rho_C: 0.758622448979592 rho_R: 0.1802040816326531
# zeta_2: 0.05 zeta_4: 0.1 rho_C: 0.6527499999999999 rho_R: 0.19365000000000004
# zeta_2: 0.05 zeta_4: 0.15000000000000002 rho_C: 0.6045108695652173 rho_R: 0.12489130434782612
# zeta_2: 0.05 zeta_4: 0.2 rho_C: 0.6738775510204082 rho_R: 0.15556122448979595
# zeta_2: 0.05 zeta_4: 0.25 rho_C: 0.6552551020408164 rho_R: 0.15443877551020413
# zeta_2: 0.1 zeta_4: 0.05 rho_C: 0.5617857142857143 rho_R: 0.03239795918367342
# zeta_2: 0.1 zeta_4: 0.1 rho_C: 0.42914999999999986 rho_R: 0.002550000000000001
# zeta_2: 0.1 zeta_4: 0.15000000000000002 rho_C: 0.42949999999999994 rho_R: 0.0026500000000000013
# zeta_2: 0.1 zeta_4: 0.2 rho_C: 0.4957000000000001 rho_R: 0.002950000000000001
# zeta_2: 0.1 zeta_4: 0.25 rho_C: 0.6507499999999999 rho_R: 0.0028500000000000014
# zeta_2: 0.15000000000000002 zeta_4: 0.05 rho_C: 0.5736000000000001 rho_R: 0.0030500000000000015
# zeta_2: 0.15000000000000002 zeta_4: 0.1 rho_C: 0.6277000000000001 rho_R: 0.0029000000000000015
# zeta_2: 0.15000000000000002 zeta_4: 0.15000000000000002 rho_C: 0.6373 rho_R: 0.0029000000000000015
# zeta_2: 0.15000000000000002 zeta_4: 0.2 rho_C: 0.5580499999999998 rho_R: 0.0027000000000000014
# zeta_2: 0.15000000000000002 zeta_4: 0.25 rho_C: 0.59455 rho_R: 0.0028500000000000014
# zeta_2: 0.2 zeta_4: 0.05 rho_C: 0.49870000000000003 rho_R: 0.002750000000000001
# zeta_2: 0.2 zeta_4: 0.1 rho_C: 0.612 rho_R: 0.0029000000000000015
# zeta_2: 0.2 zeta_4: 0.15000000000000002 rho_C: 0.64565 rho_R: 0.0030000000000000014
# zeta_2: 0.2 zeta_4: 0.2 rho_C: 0.51685 rho_R: 0.0028500000000000014
# zeta_2: 0.2 zeta_4: 0.25 rho_C: 0.6325999999999999 rho_R: 0.0028000000000000013
# zeta_2: 0.25 zeta_4: 0.05 rho_C: 0.7294499999999999 rho_R: 0.0031500000000000018
# zeta_2: 0.25 zeta_4: 0.1 rho_C: 0.5950000000000002 rho_R: 0.0029500000000000017
# zeta_2: 0.25 zeta_4: 0.15000000000000002 rho_C: 0.5196500000000001 rho_R: 0.0029000000000000015
# zeta_2: 0.25 zeta_4: 0.2 rho_C: 0.6763999999999999 rho_R: 0.0028000000000000013
# zeta_2: 0.25 zeta_4: 0.25 rho_C: 0.573112244897959 rho_R: 0.0028061224489795934

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Save result
df = pd.DataFrame(results_rho_R)
df.to_csv('/content/drive/My Drive/Network_Tests/rho_R_zeta2_zeta4.csv')
df2 = pd.DataFrame(results_rho_C)
df2.to_csv('/content/drive/My Drive/Network_Tests/rho_C_zeta2_zeta4.csv')

# %%
# Plot the heat map
fig, ax = plt.subplots(figsize=(4,4))
heatmap = ax.imshow(results_rho_R, cmap='plasma', interpolation='nearest')

# Set the SN-IP and SP-IN disease spreading rates
zeta_2_values = np.arange(0.1, 0.30, 0.05)
zeta_4_values = np.arange(0.1, 0.30, 0.05)

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(zeta_4_values)))
ax.set_yticks(np.arange(len(zeta_2_values)))

# Format the tick labels with two decimal places using string formatting
zeta_4_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
zeta_2_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(zeta_4_formatter)
ax.yaxis.set_major_formatter(zeta_2_formatter)
ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in zeta_4_values])
ax.set_yticklabels(['{:.2f}'.format(val) for val in zeta_2_values])

plt.xticks(rotation=45)
plt.colorbar(heatmap, fraction=0.1)

# Set labels and title
ax.set_xlabel('Protection rate by behavior $\zeta_4$')
ax.set_ylabel('Protection rate by information $\zeta_2$')
ax.set_title('Average Recovered Density Heatmap')

# Display the heat map
plt.show()

# %%
lam = 0.1
alp = 1
zeta_1 = 0.1
zeta_3 = 0.1
beta_PP = 0.025
beta_NP = 0.05
beta_PN = 0.2
beta_NN = 0.4
mu = 1
n_sample = 30

# Set the SN-IP and SP-IN disease spreading rates
zeta_2_values2 = np.arange(0.05, 0.21, 0.03)
zeta_4_values2 = np.arange(0.05, 0.21, 0.03)

# Initialize the result array
results_rho_C9 = np.zeros((len(zeta_2_values2), len(zeta_4_values2)))
results_rho_R9 = np.zeros((len(zeta_2_values2), len(zeta_4_values2)))

# Iterate over mu and lambda values
for i, zeta_2 in enumerate(zeta_2_values2):
    for j, zeta_4 in enumerate(zeta_4_values2):
        avg_rho_C9, avg_rho_P9, avg_rho_R9 = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
        results_rho_C9[i, j] = avg_rho_C9
        results_rho_R9[i, j] = avg_rho_R9
        print("zeta_2:", zeta_2, "zeta_4:", zeta_4, "rho_C:", avg_rho_C9, "rho_R:", avg_rho_R9)
# Out:
# zeta_2: 0.05 zeta_4: 0.05 rho_C: 0.7729310344827586 rho_R: 0.2275862068965518
# zeta_2: 0.05 zeta_4: 0.08 rho_C: 0.6539285714285714 rho_R: 0.1870535714285715
# zeta_2: 0.05 zeta_4: 0.11 rho_C: 0.5003571428571428 rho_R: 0.2564285714285714
# zeta_2: 0.05 zeta_4: 0.14 rho_C: 0.6177678571428571 rho_R: 0.10419642857142855
# zeta_2: 0.05 zeta_4: 0.16999999999999998 rho_C: 0.4535344827586206 rho_R: 0.15094827586206894
# zeta_2: 0.05 zeta_4: 0.2 rho_C: 0.6724074074074072 rho_R: 0.13009259259259254
# zeta_2: 0.08 zeta_4: 0.05 rho_C: 0.5869827586206897 rho_R: 0.12336206896551721
# zeta_2: 0.08 zeta_4: 0.08 rho_C: 0.7105172413793105 rho_R: 0.28051724137931033
# zeta_2: 0.08 zeta_4: 0.11 rho_C: 0.5817241379310344 rho_R: 0.11232758620689653
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-113e8e3efa1d> in <cell line: 21>()
#      21 for i, zeta_2 in enumerate(zeta_2_values2):
#      22     for j, zeta_4 in enumerate(zeta_4_values2):
# ---> 23         avg_rho_C9, avg_rho_P9, avg_rho_R9 = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
#      24         results_rho_C9[i, j] = avg_rho_C9
#      25         results_rho_R9[i, j] = avg_rho_R9
#
# <ipython-input-10-42f5beed60d9> in ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
#     235           elif event < p8:
#     236             if len(protected) > 0:
# --> 237                 node_to_not_protect = np.random.choice(protected)
#     238                 n_P = sum(1 for node in filter(lambda x: lprot[x] == "P", cnw.neighbors(node_to_not_protect)))
#     239                 k_cog = len(cnw.neighbors(node_to_not_protect))
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# _bounded_integers.pyx in numpy.random._bounded_integers._rand_int64()
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    3098     10
#    3099     """
# -> 3100     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3101                           keepdims=keepdims, initial=initial, where=where)
#    3102
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, out=out, **passkwargs)
#      87
# ---> 88     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      89
#      90
#
# KeyboardInterrupt:

# %%
# Save result
df = pd.DataFrame(results_rho_R9)
df.to_csv('/content/drive/My Drive/Network_Tests/rho_R_zeta2_zeta4_2.csv')

# %%
# Plot the heat map
fig, ax = plt.subplots(figsize=(5,5))
heatmap = ax.imshow(results_rho_R9, cmap='plasma', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(zeta_4_values2)))
ax.set_yticks(np.arange(len(zeta_2_values2)))

# Format the tick labels with two decimal places using string formatting
zeta_4_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
zeta_2_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(zeta_4_formatter)
ax.yaxis.set_major_formatter(zeta_2_formatter)
ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in zeta_4_values2])
ax.set_yticklabels(['{:.2f}'.format(val) for val in zeta_2_values2])

plt.xticks(rotation=45)
plt.colorbar(heatmap, fraction=0.04)

# Set labels and title
ax.set_xlabel('Protection rate by behavior $\zeta_4$')
ax.set_ylabel('Protection rate by information $\zeta_2$')
ax.set_title('Average Recovered Density Heatmap')

# Display the heat map
plt.show()

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
lam = 0.1
alp = 1
zeta_2 = 0.1
zeta_4 = 0.1
beta_PP = 0.025
beta_NP = 0.05
beta_PN = 0.2
beta_NN = 0.4
mu = 1
n_sample = 50

# Set the SN-IP and SP-IN disease spreading rates
zeta_1_values2 = np.arange(0.1, 0.5, 0.1)
zeta_3_values2 = np.arange(0.1, 0.5, 0.1)

# Initialize the result array
results_rho_C4 = np.zeros((len(zeta_1_values2), len(zeta_3_values2)))
results_rho_R4 = np.zeros((len(zeta_1_values2), len(zeta_3_values2)))

# Iterate over mu and lambda values
for i, zeta_1 in enumerate(zeta_1_values2):
    for j, zeta_3 in enumerate(zeta_3_values2):
        avg_rho_C4, avg_rho_P4, avg_rho_R4 = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
        results_rho_C4[i, j] = avg_rho_C4
        results_rho_R4[i, j] = avg_rho_R4
        print("zeta_1:", zeta_1, "zeta_3:", zeta_3, "rho_C:", avg_rho_C4, "rho_R:", avg_rho_R4)
# Out:
# zeta_1: 0.1 zeta_3: 0.1 rho_C: 0.5818367346938776 rho_R: 0.0032142857142857155
# zeta_1: 0.1 zeta_3: 0.2 rho_C: 0.6399499999999999 rho_R: 0.002750000000000001
# zeta_1: 0.1 zeta_3: 0.30000000000000004 rho_C: 0.6417000000000002 rho_R: 0.0027000000000000014
# zeta_1: 0.1 zeta_3: 0.4 rho_C: 0.6592999999999998 rho_R: 0.0029500000000000017
# zeta_1: 0.2 zeta_3: 0.1 rho_C: 0.5936224489795918 rho_R: 0.0028571428571428584
# zeta_1: 0.2 zeta_3: 0.2 rho_C: 0.7253260869565218 rho_R: 0.42576086956521747
# zeta_1: 0.2 zeta_3: 0.30000000000000004 rho_C: 0.6992346938775511 rho_R: 0.6055612244897959
# zeta_1: 0.2 zeta_3: 0.4 rho_C: 0.5747093023255813 rho_R: 0.500872093023256
# zeta_1: 0.30000000000000004 zeta_3: 0.1 rho_C: 0.6367021276595745 rho_R: 0.27643617021276584
# zeta_1: 0.30000000000000004 zeta_3: 0.2 rho_C: 0.7431382978723406 rho_R: 0.41489361702127653
# zeta_1: 0.30000000000000004 zeta_3: 0.30000000000000004 rho_C: 0.6823863636363636 rho_R: 0.46772727272727294
# zeta_1: 0.30000000000000004 zeta_3: 0.4 rho_C: 0.761510416666667 rho_R: 0.39114583333333347
# zeta_1: 0.4 zeta_3: 0.1 rho_C: 0.6473958333333335 rho_R: 0.31583333333333335
# zeta_1: 0.4 zeta_3: 0.2 rho_C: 0.7324468085106383 rho_R: 0.4382446808510639
# zeta_1: 0.4 zeta_3: 0.30000000000000004 rho_C: 0.5621938775510203 rho_R: 0.4653061224489796
# zeta_1: 0.4 zeta_3: 0.4 rho_C: 0.7411111111111108 rho_R: 0.5231666666666667

# %%
# Plot the heat map
fig, ax = plt.subplots(figsize=(4,4))
heatmap = ax.imshow(results_rho_R4, cmap='plasma', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(zeta_3_values2)))
ax.set_yticks(np.arange(len(zeta_1_values2)))

# Format the tick labels with two decimal places using string formatting
zeta_3_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
zeta_1_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(zeta_3_formatter)
ax.yaxis.set_major_formatter(zeta_1_formatter)
ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in zeta_3_values2])
ax.set_yticklabels(['{:.2f}'.format(val) for val in zeta_1_values2])

plt.xticks(rotation=45)
plt.colorbar(heatmap, fraction=0.04)

# Set labels and title
ax.set_xlabel('Protection rate by behavior $\zeta_3$')
ax.set_ylabel('Protection rate by information $\zeta_1$')
ax.set_title('Average Recovered Density Heatmap')

# Display the heat map
plt.show()

# %%
lam = 0.1
alp = 1
zeta_2 = 0.1
zeta_4 = 0.1
beta_PP = 0.025
beta_NP = 0.05
beta_PN = 0.2
beta_NN = 0.4
mu = 1
n_sample = 50

# Set the SN-IP and SP-IN disease spreading rates
zeta_1_values3 = np.arange(0.1, 0.5, 0.05)
zeta_3_values3 = np.arange(0.1, 0.5, 0.05)

# Initialize the result array
results_rho_C8 = np.zeros((len(zeta_1_values3), len(zeta_3_values3)))
results_rho_R8 = np.zeros((len(zeta_1_values3), len(zeta_3_values3)))

# Iterate over mu and lambda values
for i, zeta_1 in enumerate(zeta_1_values3):
    for j, zeta_3 in enumerate(zeta_3_values3):
        avg_rho_C8, avg_rho_P8, avg_rho_R8 = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
        results_rho_C8[i, j] = avg_rho_C8
        results_rho_R8[i, j] = avg_rho_R8
        print("zeta_1:", zeta_1, "zeta_3:", zeta_3, "rho_C:", avg_rho_C8, "rho_R:", avg_rho_R8)
# Out:
# zeta_1: 0.1 zeta_3: 0.1 rho_C: 0.5750000000000001 rho_R: 0.023316326530612195
# zeta_1: 0.1 zeta_3: 0.15000000000000002 rho_C: 0.7564499999999996 rho_R: 0.0036000000000000016
# zeta_1: 0.1 zeta_3: 0.20000000000000004 rho_C: 0.5791999999999998 rho_R: 0.0037000000000000023
# zeta_1: 0.1 zeta_3: 0.25000000000000006 rho_C: 0.7299499999999998 rho_R: 0.003950000000000002
# zeta_1: 0.1 zeta_3: 0.30000000000000004 rho_C: 0.588265306122449 rho_R: 0.003724489795918369
# zeta_1: 0.1 zeta_3: 0.3500000000000001 rho_C: 0.6302551020408161 rho_R: 0.0034183673469387775
# zeta_1: 0.1 zeta_3: 0.40000000000000013 rho_C: 0.66345 rho_R: 0.0033000000000000017
# zeta_1: 0.1 zeta_3: 0.45000000000000007 rho_C: 0.7179999999999999 rho_R: 0.003900000000000002
# zeta_1: 0.15000000000000002 zeta_3: 0.1 rho_C: 0.6865760869565218 rho_R: 0.11695652173913049
# zeta_1: 0.15000000000000002 zeta_3: 0.15000000000000002 rho_C: 0.7696195652173914 rho_R: 0.7861413043478261
# zeta_1: 0.15000000000000002 zeta_3: 0.20000000000000004 rho_C: 0.5930113636363635 rho_R: 0.7113636363636365
# zeta_1: 0.15000000000000002 zeta_3: 0.25000000000000006 rho_C: 0.7652380952380954 rho_R: 0.7246428571428571
# zeta_1: 0.15000000000000002 zeta_3: 0.30000000000000004 rho_C: 0.6875568181818181 rho_R: 0.6884659090909092
# zeta_1: 0.15000000000000002 zeta_3: 0.3500000000000001 rho_C: 0.6159239130434783 rho_R: 0.8297826086956522
# zeta_1: 0.15000000000000002 zeta_3: 0.40000000000000013 rho_C: 0.6380319148936171 rho_R: 0.8131382978723405
# zeta_1: 0.15000000000000002 zeta_3: 0.45000000000000007 rho_C: 0.7572619047619048 rho_R: 0.7441666666666669
# zeta_1: 0.20000000000000004 zeta_3: 0.1 rho_C: 0.7245212765957446 rho_R: 0.5141489361702128

# %%
# Plot the heat map
fig, ax = plt.subplots(figsize=(4,4))
heatmap = ax.imshow(results_rho_R8, cmap='plasma', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(zeta_3_values3)))
ax.set_yticks(np.arange(len(zeta_1_values3)))

# Format the tick labels with two decimal places using string formatting
zeta_3_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
zeta_1_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(zeta_3_formatter)
ax.yaxis.set_major_formatter(zeta_1_formatter)
ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in zeta_3_values3])
ax.set_yticklabels(['{:.2f}'.format(val) for val in zeta_1_values3])

plt.xticks(rotation=45)
plt.colorbar(heatmap, fraction=0.04)

# Set labels and title
ax.set_xlabel('Protection rate by behavior $\zeta_3$')
ax.set_ylabel('Protection rate by information $\zeta_1$')
ax.set_title('Average Recovered Density Heatmap')

# Display the heat map
plt.show()

# %%
lam = 0.1
alp = 1
zeta_2 = 0.1
zeta_4 = 0.1
beta_PP = 0.025
beta_NP = 0.05
beta_PN = 0.2
beta_NN = 0.4
mu = 1
n_sample = 50

# Set the SN-IP and SP-IN disease spreading rates
zeta_1_values = np.arange(0.15, 0.31, 0.05)
zeta_3_values = np.arange(0.05, 0.21, 0.05)

# Initialize the result array
results_rho_C2 = np.zeros((len(zeta_1_values), len(zeta_3_values)))
results_rho_R2 = np.zeros((len(zeta_1_values), len(zeta_3_values)))

# Iterate over mu and lambda values
for i, zeta_1 in enumerate(zeta_1_values):
    for j, zeta_3 in enumerate(zeta_3_values):
        avg_rho_C2, avg_rho_P2, avg_rho_R2 = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
        results_rho_C2[i, j] = avg_rho_C2
        results_rho_R2[i, j] = avg_rho_R2
        print("zeta_1:", zeta_1, "zeta_3:", zeta_3, "rho_C:", avg_rho_C2, "rho_R:", avg_rho_R2)
# Out:
# zeta_1: 0.15 zeta_3: 0.05 rho_C: 0.725 rho_R: 0.015499999999999953
# zeta_1: 0.15 zeta_3: 0.1 rho_C: 0.6462499999999999 rho_R: 0.0026500000000000013
# zeta_1: 0.15 zeta_3: 0.15000000000000002 rho_C: 0.6892000000000001 rho_R: 0.021400000000000002
# zeta_1: 0.15 zeta_3: 0.2 rho_C: 0.7939130434782606 rho_R: 0.57304347826087
# zeta_1: 0.2 zeta_3: 0.05 rho_C: 0.6907 rho_R: 0.0033500000000000005
# zeta_1: 0.2 zeta_3: 0.1 rho_C: 0.5666500000000001 rho_R: 0.1861000000000001
# zeta_1: 0.2 zeta_3: 0.15000000000000002 rho_C: 0.7323369565217391 rho_R: 0.45885869565217385
# zeta_1: 0.2 zeta_3: 0.2 rho_C: 0.7895408163265306 rho_R: 0.6109693877551022
# zeta_1: 0.25 zeta_3: 0.05 rho_C: 0.6865000000000001 rho_R: 0.020849999999999952
# zeta_1: 0.25 zeta_3: 0.1 rho_C: 0.6023437500000001 rho_R: 0.2230208333333333
# zeta_1: 0.25 zeta_3: 0.15000000000000002 rho_C: 0.7419499999999999 rho_R: 0.5324500000000001
# zeta_1: 0.25 zeta_3: 0.2 rho_C: 0.7935555555555556 rho_R: 0.6077222222222223
# zeta_1: 0.30000000000000004 zeta_3: 0.05 rho_C: 0.7623000000000001 rho_R: 0.019049999999999963
# zeta_1: 0.30000000000000004 zeta_3: 0.1 rho_C: 0.7864999999999995 rho_R: 0.32629999999999987
# zeta_1: 0.30000000000000004 zeta_3: 0.15000000000000002 rho_C: 0.6824489795918369 rho_R: 0.5609693877551021
# zeta_1: 0.30000000000000004 zeta_3: 0.2 rho_C: 0.8299479166666668 rho_R: 0.5464583333333333

# %%
# Plot the heat map
fig, ax = plt.subplots(figsize=(5,5))
heatmap = ax.imshow(results_rho_R2, cmap='plasma', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(zeta_3_values)))
ax.set_yticks(np.arange(len(zeta_1_values)))

# Format the tick labels with two decimal places using string formatting
zeta_3_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
zeta_1_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(zeta_3_formatter)
ax.yaxis.set_major_formatter(zeta_1_formatter)
ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in zeta_3_values])
ax.set_yticklabels(['{:.2f}'.format(val) for val in zeta_1_values])

plt.xticks(rotation=45)
plt.colorbar(heatmap, fraction=0.1)

# Set labels and title
ax.set_xlabel('No protection rate by behavior $\zeta_3$')
ax.set_ylabel('No protection rate by information $\zeta_1$')
ax.set_title('Average Recovered Density Heatmap')

# Display the heat map
plt.show()

# %%
lam = 0.1
alp = 1
zeta_2 = 0.1
zeta_4 = 0.1
beta_PP = 0.025
beta_NP = 0.05
beta_PN = 0.2
beta_NN = 0.4
mu = 1
n_sample = 100

# Set the SN-IP and SP-IN disease spreading rates
zeta_1_values3 = np.arange(0.15, 0.25, 0.03)
zeta_3_values3 = np.arange(0.05, 0.20, 0.03)

# Initialize the result array
results_rho_C6 = np.zeros((len(zeta_1_values3), len(zeta_3_values3)))
results_rho_R6 = np.zeros((len(zeta_1_values3), len(zeta_3_values3)))

# Iterate over mu and lambda values
for i, zeta_1 in enumerate(zeta_1_values3):
    for j, zeta_3 in enumerate(zeta_3_values3):
        avg_rho_C6, avg_rho_P6, avg_rho_R6 = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
        results_rho_C6[i, j] = avg_rho_C6
        results_rho_R6[i, j] = avg_rho_R6
        print("zeta_1:", zeta_1, "zeta_3:", zeta_3, "rho_C:", avg_rho_C6, "rho_R:", avg_rho_R6)
# Out:
# zeta_1: 0.15 zeta_3: 0.05 rho_C: 0.6771499999999997 rho_R: 0.003025000000000002
# zeta_1: 0.15 zeta_3: 0.1 rho_C: 0.6753535353535355 rho_R: 0.003080808080808083
# zeta_1: 0.15 zeta_3: 0.15000000000000002 rho_C: 0.7397727272727274 rho_R: 0.0029292929292929312
# zeta_1: 0.15 zeta_3: 0.2 rho_C: 0.7416578947368422 rho_R: 0.5887105263157895
# zeta_1: 0.2 zeta_3: 0.05 rho_C: 0.728333333333333 rho_R: 0.010782828282828236
# zeta_1: 0.2 zeta_3: 0.1 rho_C: 0.7644642857142852 rho_R: 0.3408163265306122
# zeta_1: 0.2 zeta_3: 0.15000000000000002 rho_C: 0.7405319148936167 rho_R: 0.5330053191489361
# zeta_1: 0.2 zeta_3: 0.2 rho_C: 0.6690860215053763 rho_R: 0.5720967741935481
# zeta_1: 0.25 zeta_3: 0.05 rho_C: 0.71845 rho_R: 0.011874999999999959
# zeta_1: 0.25 zeta_3: 0.1 rho_C: 0.7366315789473682 rho_R: 0.26942105263157917
# zeta_1: 0.25 zeta_3: 0.15000000000000002 rho_C: 0.7492287234042553 rho_R: 0.5582446808510636
# zeta_1: 0.25 zeta_3: 0.2 rho_C: 0.7650263157894738 rho_R: 0.4658157894736838
# zeta_1: 0.30000000000000004 zeta_3: 0.05 rho_C: 0.6368500000000001 rho_R: 0.004200000000000002
# zeta_1: 0.30000000000000004 zeta_3: 0.1 rho_C: 0.6995918367346936 rho_R: 0.3799489795918366
# zeta_1: 0.30000000000000004 zeta_3: 0.15000000000000002 rho_C: 0.7594662921348313 rho_R: 0.5537921348314607
# zeta_1: 0.30000000000000004 zeta_3: 0.2 rho_C: 0.7722311827956986 rho_R: 0.5412365591397849

# %%
# Plot the heat map
fig, ax = plt.subplots(figsize=(5,5))
heatmap = ax.imshow(results_rho_R6, cmap='plasma', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(zeta_3_values3)))
ax.set_yticks(np.arange(len(zeta_1_values3)))

# Format the tick labels with two decimal places using string formatting
zeta_3_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
zeta_1_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(zeta_3_formatter)
ax.yaxis.set_major_formatter(zeta_1_formatter)
ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in zeta_3_values3])
ax.set_yticklabels(['{:.2f}'.format(val) for val in zeta_1_values3])

plt.xticks(rotation=45)
plt.colorbar(heatmap, fraction=0.1)

# Set labels and title
ax.set_xlabel('No protection rate by behavior $\zeta_3$')
ax.set_ylabel('No protection rate by information $\zeta_1$')
ax.set_title('Average Recovered Density Heatmap')

# Display the heat map
plt.show()

# %%
lam = 0.1
alp = 1
zeta_2 = 0.1
zeta_4 = 0.1
beta_PP = 0.025
beta_NP = 0.05
beta_PN = 0.2
beta_NN = 0.4
mu = 1
n_sample = 50

# Set the SN-IP and SP-IN disease spreading rates
zeta_1_values2 = np.arange(0.05, 0.21, 0.05)
zeta_3_values2 = np.arange(0.05, 0.21, 0.05)

# Initialize the result array
results_rho_C3 = np.zeros((len(zeta_1_values2), len(zeta_3_values2)))
results_rho_R3 = np.zeros((len(zeta_1_values2), len(zeta_3_values2)))

# Iterate over mu and lambda values
for i, zeta_1 in enumerate(zeta_1_values2):
    for j, zeta_3 in enumerate(zeta_3_values2):
        avg_rho_C3, avg_rho_P3, avg_rho_R3 = ICE_model(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)
        results_rho_C3[i, j] = avg_rho_C3
        results_rho_R3[i, j] = avg_rho_R3
        print("zeta_1:", zeta_1, "zeta_3:", zeta_3, "rho_C:", avg_rho_C3, "rho_R:", avg_rho_R3)
# Out:
# zeta_1: 0.05 zeta_3: 0.05 rho_C: 0.6228499999999998 rho_R: 0.020249999999999956
# zeta_1: 0.05 zeta_3: 0.1 rho_C: 0.5643 rho_R: 0.0033000000000000017
# zeta_1: 0.05 zeta_3: 0.15000000000000002 rho_C: 0.6772448979591837 rho_R: 0.0030102040816326545
# zeta_1: 0.05 zeta_3: 0.2 rho_C: 0.5485500000000001 rho_R: 0.0029000000000000015
# zeta_1: 0.1 zeta_3: 0.05 rho_C: 0.6456999999999999 rho_R: 0.003100000000000001
# zeta_1: 0.1 zeta_3: 0.1 rho_C: 0.6015625 rho_R: 0.0031250000000000015
# zeta_1: 0.1 zeta_3: 0.15000000000000002 rho_C: 0.5581499999999999 rho_R: 0.003400000000000002
# zeta_1: 0.1 zeta_3: 0.2 rho_C: 0.6033500000000002 rho_R: 0.0029500000000000017
# zeta_1: 0.15000000000000002 zeta_3: 0.05 rho_C: 0.5368499999999999 rho_R: 0.0028500000000000014
# zeta_1: 0.15000000000000002 zeta_3: 0.1 rho_C: 0.64225 rho_R: 0.056400000000000006
# zeta_1: 0.15000000000000002 zeta_3: 0.15000000000000002 rho_C: 0.7846428571428571 rho_R: 0.002908163265306124
# zeta_1: 0.2 zeta_3: 0.05 rho_C: 0.6176020408163264 rho_R: 0.0032653061224489814
# zeta_1: 0.2 zeta_3: 0.1 rho_C: 0.5131999999999999 rho_R: 0.12360000000000015
# zeta_1: 0.2 zeta_3: 0.2 rho_C: 0.7467553191489359 rho_R: 0.5696276595744684

# %%
# Plot the heat map
fig, ax = plt.subplots(figsize=(5,5))
heatmap = ax.imshow(results_rho_R3, cmap='plasma', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(zeta_3_values2)))
ax.set_yticks(np.arange(len(zeta_1_values2)))

# Format the tick labels with two decimal places using string formatting
zeta_3_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
zeta_1_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(zeta_3_formatter)
ax.yaxis.set_major_formatter(zeta_1_formatter)
ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in zeta_3_values2])
ax.set_yticklabels(['{:.2f}'.format(val) for val in zeta_1_values2])

plt.xticks(rotation=45)
plt.colorbar(heatmap, fraction=0.1)

# Set labels and title
ax.set_xlabel('Protection rate by behavior $\zeta_3$')
ax.set_ylabel('Protection rate by information $\zeta_1$')
ax.set_title('Average Recovered Density Heatmap')

# Display the heat map
plt.show()
