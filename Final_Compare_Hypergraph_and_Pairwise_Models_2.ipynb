# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancy-Shi/Complex_Networks/blob/main/Final_Compare_Hypergraph_and_Pairwise_Models_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following code is used to demonstrate the result of hypergraph rumor spread on a network. In this example, the network size is 400, with degree exponent of 2.5, and minimum degree of 3. The number of hyperedges (groups) is set to 100. The heatmap shows the stifler density with varying transmission rate while setting the threshold constant to 0.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import random
import math as math
from math import log
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Part 1: Hypergraph Generation
# The following steps generate a hyper graph using the XGI/HyperNetX python package,  following power-law degree distribution for predifined number of nodes n, number of hyperedges num_hyper_edges, degree exponent gamma, using a configuration model with data stored in a dictionary.

# %%
# Step 1: Generate Degree Sequence
def generate_degree_sequence(n, gamma, kmin):
    # Generate a random set from the power law distribution
    u = np.random.uniform(size=n)
    degrees = np.ceil((1.0 - u) ** (-1.0 / (gamma - 1.0)))

    # Adjust degrees based on the minimum and maximum degree values
    kmax = int(np.sqrt(n))
    # kmax = int(1.5*n**(1/4)) # max degree allowed is 1.5*n^(1/4)
    degrees = degrees[(degrees >= kmin) & (degrees <= kmax)].astype(int)

    # Truncate or pad the sequence to match the length specified
    if len(degrees) >= n:
        degrees = degrees[:n]
    else:
        degrees = np.concatenate((degrees, np.full(n - len(degrees), kmin)))

    return degrees.tolist()

# Step 2: Generate Hyper Edge Size Sequence
def generate_hyper_edge_sizes(degrees, num_hyper_edges):
    total_degrees = sum(degrees)
    hyper_edge_sizes = []

    # Calculate the average size for each hyper edge
    avg_size = total_degrees // num_hyper_edges
    remainder = total_degrees % num_hyper_edges

    # Define the range for the random distribution
    min_size = 1  # Lower bound of the range
    max_size = len(degrees)-num_hyper_edges  # Upper bound of the range

    # Generate hyper edge sizes
    for _ in range(num_hyper_edges):
        size = random.randint(min_size, max_size)
        hyper_edge_sizes.append(size)

    return hyper_edge_sizes


# Step 3: Create Copies of Nodes
def create_node_copies(degrees):
    node_copies = []
    for i, degree in enumerate(degrees):
        for _ in range(degree):
            node_copies.append(i)
    return node_copies

# Step 4: Create Copies of Hyper Edges
def create_hyper_edge_copies(hyper_edge_sizes):
    hyper_edge_copies = []
    for i, size in enumerate(hyper_edge_sizes):
        for _ in range(size):
            hyper_edge_copies.append(i)
    return hyper_edge_copies

# Step 5: Randomly Pair Copies
def randomly_pair_copies(node_copies, hyper_edge_copies):
    random.shuffle(node_copies)
    random.shuffle(hyper_edge_copies)
    pairs = []
    for i in range(len(node_copies)):
        pairs.append((node_copies[i], hyper_edge_copies[i]))
    return pairs

# Step 6: Convert Bipartite Graph to A Hypergraph Dictionary
def convert_to_hypergraph(pairs):
    hypergraph = {}
    for pair in pairs:
        node, hyper_edge = pair
        if hyper_edge in hypergraph:
            hypergraph[hyper_edge].append(node)
        else:
            hypergraph[hyper_edge] = [node]
    return hypergraph

# %%
def build_hypergraph(n, gamma, kmin, num_hyper_edges):
    # Step 1: Generate Degree Sequence
    degrees = generate_degree_sequence(n, gamma, kmin)
    print("Degree Sequence: ", degrees)

    # Step 2: Generate Hyper Edge Size Sequence
    hyper_edge_sizes = generate_hyper_edge_sizes(degrees, num_hyper_edges)
    print("Hyper Edge Sizes: ", hyper_edge_sizes)

    # Step 3: Create Copies of Nodes
    node_copies = create_node_copies(degrees)

    # Step 4: Create Copies of Hyper Edges
    hyper_edge_copies = create_hyper_edge_copies(hyper_edge_sizes)

    # Step 5: Randomly Pair Copies
    pairs = randomly_pair_copies(node_copies, hyper_edge_copies)

    # Step 6: Convert Bipartite Graph to Hypergraph
    hyperedge_dict = convert_to_hypergraph(pairs)

    # Print the resulting hypergraph
    print("Hypergraph Dictionary: ", hyperedge_dict)

    return degrees, hyperedge_dict

# %%
# Test 1
n =50  # Number of nodes
gamma = 2.5  # Power-law exponent
kmin = 3  # Minimum degree
num_hyper_edges = 8  # Desired number of hyper edges

degrees, hyperedge_dict = build_hypergraph(n, gamma, kmin, num_hyper_edges)
# Out:
# Degree Sequence:  [3, 3, 4, 3, 3, 3, 5, 3, 3, 4, 4, 3, 3, 3, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [20, 17, 35, 15, 35, 3, 15, 37]
# Hypergraph Dictionary:  {0: [39, 19, 22, 2, 48, 31, 37, 46, 42, 37, 26, 8, 49, 32, 8], 4: [25, 35, 18, 10, 3, 44, 12, 16, 7, 43, 33, 34, 36, 42, 43, 43, 29, 7, 38, 17, 23, 40, 12, 30, 4, 41, 48, 45, 22, 6, 21, 13, 19, 1, 5], 2: [14, 24, 38, 1, 14, 13, 2, 47, 18, 29, 21, 15, 49, 9, 2, 44, 27, 16, 4, 5, 44, 29, 45, 6, 40, 17, 46, 16, 33, 8, 11, 35], 7: [31, 41, 25, 12, 25, 6, 3, 19, 0, 15, 11, 24, 20, 18, 14, 46, 28, 45, 4, 39, 0, 10, 22, 26, 9, 41, 23, 23, 32, 9, 14], 1: [0, 32, 34, 10, 39, 33, 3, 15, 31, 15, 49, 37, 13, 27, 34, 20], 3: [21, 47, 26, 40, 47, 7, 36, 38, 5, 48, 20, 30], 6: [16, 35, 28, 28, 6, 11, 1, 10, 36, 9, 6, 2, 30, 17], 5: [42, 27, 24]}

# %%
# Plot the hypergraph
# !pip install hypernetx
import hypernetx as hnx
H = hnx.Hypergraph(hyperedge_dict)
plt.subplots(figsize=(5,5))
hnx.draw(H)
# Out:
# Collecting hypernetx
#   Downloading hypernetx-2.0.3-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 2.2 MB/s eta 0:00:00
# Collecting networkx<3.0,>=2.2 (from hypernetx)
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.0 MB/s eta 0:00:00
# Collecting numpy<2.0,>=1.24.0 (from hypernetx)
#   Downloading numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.10.1)
# Requirement already satisfied: matplotlib>3.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.2.2)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.5.3)
# Collecting decorator>=5.1.1 (from hypernetx)
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->hypernetx) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->hypernetx) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->hypernetx) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>3.0->hypernetx) (1.16.0)
# Installing collected packages: numpy, networkx, decorator, hypernetx
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.2 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.2 which is incompatible.
# Successfully installed decorator-5.1.1 hypernetx-2.0.3 networkx-2.8.8 numpy-1.25.2
#  No module named 'igraph'. If you need to use hypernetx.algorithms.hypergraph_modularity, please install additional packages by running the following command: pip install .['all']

# %%
# Test 2
n2 =400  # Number of nodes
gamma2 = 2.5  # Power-law exponent
kmin2 = 3  # Minimum degree
num_hyper_edges2 = 100  # Desired number of hyper edges

degrees2, hyperedge_dict2 = build_hypergraph(n2, gamma2, kmin2, num_hyper_edges2)
H2 = hnx.Hypergraph(hyperedge_dict2)
# Out:
# Degree Sequence:  [3, 6, 3, 6, 3, 3, 5, 4, 3, 3, 4, 3, 4, 4, 4, 3, 5, 3, 5, 11, 3, 16, 4, 3, 5, 5, 3, 3, 6, 3, 5, 3, 9, 3, 5, 3, 12, 5, 4, 4, 4, 8, 5, 4, 3, 3, 14, 3, 3, 9, 5, 3, 6, 3, 7, 4, 4, 3, 4, 3, 4, 3, 3, 8, 5, 3, 3, 3, 9, 3, 3, 8, 4, 3, 4, 18, 7, 5, 3, 4, 3, 3, 3, 3, 6, 6, 3, 8, 6, 6, 3, 7, 4, 3, 3, 3, 5, 3, 4, 6, 3, 3, 4, 5, 4, 3, 3, 3, 4, 6, 4, 3, 4, 4, 3, 5, 18, 9, 6, 13, 4, 5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [1, 194, 37, 192, 281, 25, 83, 206, 192, 238, 223, 148, 264, 288, 68, 115, 52, 149, 181, 269, 4, 47, 44, 196, 157, 233, 161, 48, 121, 43, 127, 209, 246, 207, 192, 161, 27, 218, 253, 113, 253, 251, 76, 146, 7, 13, 283, 295, 281, 271, 162, 183, 37, 234, 259, 169, 201, 180, 86, 263, 136, 57, 50, 152, 266, 202, 124, 272, 275, 173, 104, 190, 57, 9, 174, 188, 215, 190, 58, 275, 172, 233, 111, 163, 177, 248, 103, 55, 275, 197, 239, 267, 38, 72, 3, 147, 241, 28, 188, 193]
# Hypergraph Dictionary:  {58: [318, 191, 46, 273, 271, 349, 68, 224, 24, 149, 186, 225, 78, 247], 27: [194, 214, 58, 1, 396], 11: [163, 323, 41, 195, 314, 6, 221, 135, 120, 302, 388, 398, 244], 19: [105, 54, 205, 89, 114, 121, 121, 76, 141, 305, 3, 357, 86, 31, 176, 318, 371], 34: [349, 351, 331, 200, 110, 35, 160, 22, 76, 231, 37, 116, 73, 118, 142, 140, 308], 68: [371, 138, 261, 222, 32, 89, 379, 194, 119, 277, 214, 156, 384, 2, 327, 250, 352, 30, 117, 280, 184, 48, 80, 109, 31, 111, 313, 293, 129, 17], 65: [222, 139, 205, 92, 148, 390, 162, 123, 159, 21, 127, 32, 102, 166, 385, 136], 84: [165, 48, 47, 116, 22, 131, 130, 41, 218, 215, 269, 183, 112, 93, 100, 170, 221, 144], 26: [386, 277, 330, 68, 300, 170, 319, 27, 327, 392, 334, 34, 27, 276, 87, 171, 159, 81, 145, 34, 256], 12: [30, 152, 332, 167, 23, 58, 50, 115, 395, 274, 85, 68, 366, 306, 6, 122, 99, 68, 234, 141, 351], 28: [57, 88, 347, 232, 84, 29, 153, 187, 368, 18, 82, 75, 336], 2: [99, 202], 7: [119, 206, 293, 116, 56, 335, 175, 68, 264, 63, 210, 45, 271, 119, 219, 243, 333, 236, 288, 208], 17: [397, 28, 39, 43, 265, 278, 361, 215, 207, 43, 291], 46: [59, 287, 236, 108, 283, 251, 190, 120, 88, 395, 304, 110, 238, 361, 96, 166, 285, 16, 147, 267, 157, 346, 381, 14, 200, 176, 242], 9: [207, 184, 295, 187, 367, 198, 32, 267, 32, 128, 234, 72, 252, 72, 343, 79], 48: [201, 181, 326, 37, 386, 3, 85, 304, 143, 218, 280, 161, 253, 70, 283, 229, 85, 114, 45, 322, 203, 50, 155, 194, 62, 225], 59: [36, 180, 320, 70, 164, 91, 395, 46, 101, 161, 126, 335, 310, 329, 197, 360, 169, 3], 90: [343, 142, 294, 359, 65, 23, 196, 87, 303, 363, 76, 303, 296, 22, 223, 116, 273, 78, 116], 79: [273, 32, 61, 117, 78, 163, 172, 177, 15, 264, 71, 85, 299, 387, 315, 199, 104, 162, 108, 14, 295], 66: [396, 99, 7, 316, 98, 324, 248, 233], 37: [108, 263, 358, 71, 155, 26, 53, 75, 41, 344, 75, 268, 44, 206, 98, 88, 224, 37, 219, 186, 290], 13: [368, 0, 75, 179, 249, 4, 88, 103, 310, 201, 118, 173, 109, 348, 209, 110, 220, 30, 0, 36, 20, 30, 39, 96, 99, 68, 352, 118, 130, 233, 244, 166, 83, 285], 8: [109, 188, 246, 138, 376, 307, 28, 74, 363, 19, 36, 306, 116, 254, 150, 364, 268, 303, 76, 132, 89], 54: [316, 100, 25, 21, 213, 92, 40, 196, 24, 359, 7, 371, 14, 56, 13, 284, 137, 116, 67, 137, 52, 116, 12, 341], 1: [10, 121, 144, 75, 254, 321, 66, 42, 305, 1, 113, 118, 135, 11, 398, 282, 251], 83: [82, 375, 370, 115, 38, 232, 311, 16, 49, 241, 322], 51: [153, 38, 205, 35, 72, 212, 274, 117, 85, 153, 204, 116, 285, 28, 197, 313, 315, 147], 32: [64, 74, 49, 17, 123, 87, 137, 76, 193, 52, 18, 294, 385, 119, 230, 197, 62, 185, 60, 22, 119], 35: [42, 392, 240, 356, 346, 394, 279, 87, 236, 207, 209, 34, 3, 69, 125, 102, 107, 329, 95], 74: [377, 21, 327, 106, 183, 63, 226, 32, 89, 374, 164, 358, 89, 383, 36, 223, 175, 52], 88: [317, 87, 53, 64, 56, 267, 125, 131, 91, 136, 240, 255, 170, 146, 330, 149, 84, 380, 96, 255, 73, 383, 154, 337, 275, 75, 146, 399], 10: [29, 15, 382, 287, 6, 169, 116, 309, 117, 247, 112, 319, 49, 180, 119, 134, 384, 74, 59, 389, 103, 333, 61], 85: [281, 76, 71, 252, 36, 189, 11, 71, 88, 228, 215, 54, 367, 217, 214, 307, 18, 376, 49, 131, 7, 9], 4: [183, 189, 147, 362, 210, 223, 122, 133, 318, 172, 6, 219, 102, 334, 9, 254, 33, 206, 1, 126, 96, 10, 19, 341, 37, 185, 156, 297], 15: [119, 329, 266, 281, 68, 116, 34, 75, 28, 49, 261], 47: [393, 312, 229, 84, 154, 240, 117, 298, 126, 286, 265, 389, 325, 163, 151, 43, 130, 46, 195, 90, 76, 69, 34, 55, 108, 79, 228], 70: [269, 165, 63, 56, 265, 270, 196, 60, 65, 393], 23: [330, 81, 295, 199, 241, 370, 391, 148, 144, 238, 134, 74, 114, 347, 391, 107, 261], 40: [258, 248, 336, 192, 204, 325, 182, 381, 328, 94, 41, 333, 46, 213, 342, 355, 345, 388, 241, 257, 58, 124, 382, 105, 116], 25: [306, 42, 360, 39, 52, 290, 113, 266, 8, 69, 337, 79, 290, 302, 112, 300, 323, 326, 276], 96: [21, 129, 17, 277, 33, 111, 21, 222, 11, 195, 1, 260, 192, 245, 257, 101, 95, 133], 38: [63, 373, 41, 256, 18, 325, 168, 116, 350, 36, 35, 38, 46, 28, 345, 83, 244], 67: ...

# %%
# Test 3
n3 =400  # Number of nodes
gamma3 = 2.5  # Power-law exponent
kmin3 = 3  # Minimum degree
num_hyper_edges3 = 100  # Desired number of hyper edges

degrees3, hyperedge_dict3 = build_hypergraph(n3, gamma3, kmin3, num_hyper_edges3)
H3 = hnx.Hypergraph(hyperedge_dict3)
# Out:
# Degree Sequence:  [18, 3, 4, 3, 10, 3, 3, 5, 10, 3, 3, 5, 4, 7, 5, 20, 6, 3, 4, 3, 15, 8, 3, 4, 20, 3, 3, 3, 3, 3, 3, 3, 12, 3, 3, 7, 8, 3, 3, 3, 8, 4, 18, 6, 4, 3, 4, 6, 6, 7, 3, 3, 3, 3, 4, 4, 14, 4, 3, 3, 3, 4, 4, 5, 10, 3, 3, 7, 3, 8, 9, 3, 6, 3, 3, 4, 3, 3, 7, 18, 4, 3, 3, 3, 4, 5, 10, 12, 7, 3, 3, 3, 3, 6, 3, 3, 6, 5, 13, 10, 4, 3, 3, 3, 3, 4, 3, 6, 7, 8, 5, 3, 3, 4, 4, 3, 4, 9, 6, 6, 3, 3, 3, 4, 3, 7, 3, 3, 5, 3, 6, 5, 3, 3, 6, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [260, 130, 189, 5, 143, 144, 230, 53, 5, 207, 291, 294, 295, 17, 286, 131, 123, 76, 123, 130, 124, 18, 60, 137, 3, 36, 238, 153, 150, 143, 117, 269, 157, 139, 113, 106, 180, 121, 7, 89, 14, 26, 70, 70, 149, 274, 87, 140, 112, 289, 69, 112, 30, 228, 200, 36, 17, 19, 130, 32, 20, 147, 287, 22, 10, 155, 190, 263, 222, 41, 18, 8, 225, 79, 216, 5, 292, 66, 171, 59, 105, 291, 211, 77, 84, 10, 290, 246, 198, 32, 105, 191, 187, 10, 260, 240, 267, 1, 260, 58]
# Hypergraph Dictionary:  {81: [369, 87, 348, 183, 234, 366, 387, 63, 324, 254, 251, 358, 217, 130, 196, 301, 385, 209, 30, 258, 263, 304, 16, 221, 282, 205], 1: [378, 251, 41, 281, 330, 365, 311, 56, 24, 96, 146, 108, 74, 48, 89, 19], 76: [80, 103, 114, 42, 106, 125, 22, 172, 264, 250, 317, 197, 334, 28, 44, 67, 78, 56, 47, 187, 246, 212, 104, 263, 352, 353, 354, 337, 52, 329, 345, 13, 97, 72, 20, 8, 98], 42: [184, 389, 50, 4, 78, 218, 15, 392], 31: [93, 260, 305, 367, 370, 38, 382, 52, 125, 188, 334, 219, 101, 148, 47, 46, 49, 119, 123, 86, 100, 192, 24], 43: [81, 42, 34, 80, 113, 388, 21, 165, 365, 67, 65, 280, 62, 159, 200], 2: [35, 25, 99, 20, 347, 253, 308, 288, 291, 101, 208, 98, 86, 45, 398, 235, 392, 197, 174, 138, 160, 60, 123, 236], 67: [324, 224, 314, 108, 64, 57, 224, 125, 40, 68, 283, 107, 32, 375, 297, 235, 363, 188, 10, 248, 6, 278, 348, 279, 64, 36, 201, 255, 312, 79, 175, 130, 303, 249, 379, 266, 47], 53: [186, 333, 355, 86, 10, 99, 283, 116, 0, 203, 287, 56, 369, 337, 233, 395, 107, 233, 99, 199, 15, 20, 44, 16, 89], 33: [283, 4, 176, 342, 220, 108, 200, 158, 310, 371, 228, 18, 377, 158, 6, 321, 199], 78: [66, 49, 270, 118, 0, 88, 70, 122, 329, 254, 335, 2, 67, 28, 78, 15, 87, 185, 161, 13, 20, 166, 84], 18: [396, 93, 304, 39, 169, 119, 390, 48, 332, 240], 69: [170, 206, 16, 15, 237, 372], 25: [99, 319, 133, 32, 18, 166, 79], 49: [8, 72, 74, 225, 74, 153, 75, 319, 86, 32, 296, 288, 195, 252, 346, 69, 331, 24, 209, 199, 392, 320, 40, 221, 56, 83, 212, 201, 373, 12, 65, 211], 48: [310, 96, 11, 64, 398, 222, 217, 32, 243, 51, 187, 338, 357, 266, 86, 349, 399], 66: [157, 144, 191, 259, 155, 71, 150, 290, 92, 24, 308, 297, 231, 44, 318, 373, 259, 67, 54, 169, 341, 264, 369, 158, 134, 306, 8], 95: [310, 385, 111, 386, 13, 0, 5, 58, 109, 387, 322, 312, 351, 362, 242, 121, 328, 97, 346, 235, 303, 338, 254, 100, 56], 44: [108, 87, 148, 387, 36, 151, 156, 236, 16, 380, 167, 75, 147, 98, 21, 397, 15], 91: [230, 285, 136, 286, 79, 179, 32, 111, 152, 67, 326, 263, 32, 377, 53, 56, 76, 56, 298, 119, 76], 15: [212, 70, 358, 376, 78, 303, 113], 65: [24, 221, 93, 258, 117, 280, 18, 1, 24, 373, 42, 307, 381, 40, 144, 368], 36: [104, 135, 292, 244, 129, 252, 54, 108, 351, 383, 75, 139, 364, 98, 340, 334, 21, 11, 31, 78, 219], 58: [15, 68, 98, 88, 313, 218, 126, 292, 13, 105, 13, 165, 2], 74: [65, 349, 9, 176, 3, 393, 85, 217, 153, 344, 109, 273, 371, 56, 118, 195, 196, 83, 307, 206, 250, 44, 372, 110, 127, 91, 304, 35], 45: [142, 332, 315, 98, 73, 326, 15, 181, 36, 227, 20, 56, 49, 140, 180, 90, 42, 3, 69, 2, 246, 12, 24, 25, 295], 39: [128, 364, 54, 121, 243, 79, 391, 14, 8, 194, 27, 201, 58], 96: [338, 317, 98, 268, 42, 42, 85, 101, 34, 262, 88, 36, 361, 267, 397, 382, 232, 245, 354, 325, 125, 210, 0, 145, 361, 321, 182, 339], 98: [312, 43, 0, 71, 163, 292, 224, 63, 79, 134, 21, 284, 358, 343, 19, 53, 139, 291, 214, 298, 125, 347, 296, 294, 122, 80, 289, 30, 265, 0, 68], 4: [98, 91, 306, 189, 271, 375, 148, 88, 164, 11, 275, 12, 374, 131], 37: [140, 99, 181, 371, 17, 329, 192, 110, 42, 314, 108], 54: [87, 173, 43, 157, 279, 87, 127, 0, 355, 359, 4, 356, 15, 151, 0, 99, 83, 81, 237, 48, 268, 117, 313, 195, 137, 229, 116, 52, 190, 134, 86, 393, 64, 15, 247, 223, 345], 0: [309, 115, 98, 216, 194, 116, 347, 131, 123, 230, 0, 24, 261, 269, 98, 79, 61, 352, 291, 242, 255, 70, 160, 22, 87, 276, 109, 49, 164, 85, 77, 117, 2, 323, 388, 26, 79, 69, 189, 243, 70, 234], 86: [48, 339, 131, 117, 4, 117, 156, 237, 383, 198, 42, 187, 23, 35, 119, 120, 15, 274, 398, 16, 214, 308, 24, 60, 76, 238, 351, 77, 191, 208], 94: [152, 229, 265, 70, 215, 142, 0, 184, 214, 120, 275, 320, 115, 132, 321, 333, 215, 309, 360, 118, 342, 49, 219, 24, 250, 370, 103, 270], 11: [14, 130, 33, 370, 46, 13, 227, 227, 232, 61, 186, 245, 7, 79, 289, 226, 38, 94, 176, 62, 330, 4, 256, 335, 276, 66, 54, 39, 274, 301, 98, 180, 394, 109, 127, 42, 265, 99, 21], 82: [24, 115, 192, 143, 162, 26, 43, 109, 90, 109, 376, 36, 367, 43, 331], 10: [56, 47, 257, 15, 249, 246, 20, 31 ...

# %% [markdown]
# ## Part 2: Assign Threshold
# The following steps assigns a threshold value to each node in the network. The threshold follows a uniform or normal distribution with predefined mean (mu) and standard deviation (sigma).

# %%
import numpy as np
import random

# Defines the parameters to be used
mu = 0.1
sigma = 0.05

# Function to assign thresholds to the individual nodes
def assign_thresholds(hypergraph):
    NV = hypergraph.order()
    Ltre = {}

    for node in hypergraph.nodes():
          # Uniform distribution: #
          #Ltre[node] = np.random.uniform()
          # Normal distrution
          while True:
              threshold = random.gauss(mu, sigma)
              if 0 < threshold < 1:
                  break
          Ltre[node] = threshold

    return Ltre

Ltre = assign_thresholds(H)

print("Threshold List for Nodes: ", Ltre )
# Out:
# Threshold List for Nodes:  {0: 0.021813229425895503, 1: 0.1258144006859339, 2: 0.11303635660168568, 3: 0.12212694077836078, 4: 0.05035976904321955, 5: 0.1279185701807338, 6: 0.0021903569201629502, 7: 0.17939314659113356, 8: 0.11118308099119646, 9: 0.03825862052515573, 10: 0.129061614640716, 11: 0.10399677827395636, 12: 0.05803876969719685, 13: 0.1675444713505773, 14: 0.13345399473221572, 15: 0.10611527023421968, 16: 0.1814750128428806, 17: 0.1875722075332279, 18: 0.17002015393932604, 19: 0.08390855323637943, 20: 0.05080215981080431, 21: 0.1778730098323847, 22: 0.07269111412947034, 23: 0.0922501020537034, 24: 0.1466246872095584, 25: 0.08313944099098924, 26: 0.023577027934337122, 27: 0.03814527941685736, 28: 0.164835222792517, 29: 0.16307862778739576, 30: 0.11446388699505243, 31: 0.18121870500367795, 32: 0.09015168754488855, 33: 0.1297366730157269, 34: 0.07722005827850988, 35: 0.10115326896502085, 36: 0.12421773975793052, 37: 0.15849162724649027, 38: 0.25454140394170094, 39: 0.000546192416141289, 40: 0.06985428456269777, 41: 0.10890323996366297, 42: 0.11841296837464386, 43: 0.12988932294111927, 44: 0.14161482297524905, 45: 0.11473332724639802, 46: 0.1087763915373905, 47: 0.05814366801781873, 48: 0.14253120823045098, 49: 0.04092994468273145}

# %%
Ltre2 = assign_thresholds(H2)

print("Threshold List for Nodes: ", Ltre2 )
# Out:
# Threshold List for Nodes:  {0: 0.1122870867599439, 1: 0.08912456471342517, 2: 0.055938746326901524, 3: 0.0828070836235778, 4: 0.09669215934601583, 5: 0.18385648835255888, 6: 0.1722455081151908, 7: 0.025135767338784226, 8: 0.10599173218756, 9: 0.10304994634053878, 10: 0.1036039156855694, 11: 0.11108809458831188, 12: 0.0709626373634808, 13: 0.018260219310933343, 14: 0.07970249477089181, 15: 0.1010775923051498, 16: 0.124353408276527, 17: 0.0487599837623257, 18: 0.07656818020432897, 19: 0.12257348354838064, 20: 0.10836833724418134, 21: 0.035306992967620424, 22: 0.08842630407461671, 23: 0.00984051005487556, 24: 0.09287027694864225, 25: 0.20612594775108847, 26: 0.03944386612160007, 27: 0.05002980093521941, 28: 0.15192697932884752, 29: 0.08424036237187388, 30: 0.05072624182662851, 31: 0.019621009736011302, 32: 0.17679370113312526, 33: 0.01636174125807545, 34: 0.1649717487316858, 35: 0.11853498985938804, 36: 0.1414444007777103, 37: 0.07646225589391277, 38: 0.14164042700079643, 39: 0.06571218075335372, 40: 0.04882108201393962, 41: 0.14852571883801718, 42: 0.10737139255339204, 43: 0.1144058793381176, 44: 0.10019738550015894, 45: 0.10841251627069967, 46: 0.06303921986741845, 47: 0.16035989107429507, 48: 0.05179919378253202, 49: 0.11213482865343834, 50: 0.09241886757564499, 51: 0.09707011494016392, 52: 0.09672170289462272, 53: 0.08551958861128976, 54: 0.05233584678915212, 55: 0.12155629187796474, 56: 0.13880282489760545, 57: 0.07406382454967103, 58: 0.13611340336191163, 59: 0.07089467138664343, 60: 0.0690031000751979, 61: 0.1153092658486075, 62: 0.20537724928875445, 63: 0.07254832148655176, 64: 0.18572262342402684, 65: 0.023606185631104865, 66: 0.12997250699250407, 67: 0.07804573616168833, 68: 0.19637663701354868, 69: 0.157376977118694, 70: 0.14489028284172512, 71: 0.10700175704758629, 72: 0.09581047658464592, 73: 0.0780262431261279, 74: 0.05671438709652344, 75: 0.21119930432266965, 76: 0.10287760380973567, 77: 0.07463181288399696, 78: 0.10863842883936876, 79: 0.12854970001261345, 80: 0.17287870667073946, 81: 0.10756898987092774, 82: 0.05267621107556602, 83: 0.13618940361767692, 84: 0.17168428875682962, 85: 0.18285308448479598, 86: 0.116708458525553, 87: 0.08879182843848157, 88: 0.09251943296286431, 89: 0.052366717663562205, 90: 0.10361248543697539, 91: 0.17023807443246275, 92: 0.08563269877440033, 93: 0.057947858366316114, 94: 0.0888462131699462, 95: 0.12802994350479657, 96: 0.10666933970739627, 97: 0.09327748998033818, 98: 0.043469119947699246, 99: 0.157734252250623, 100: 0.025033859215899637, 101: 0.08733015405163622, 102: 0.15870137771612222, 103: 0.046796488957254204, 104: 0.06363221641805836, 105: 0.11446444414899473, 106: 0.013571447224387884, 107: 0.09809309574418225, 108: 0.15713310051075052, 109: 0.09935655588496231, 110: 0.19049045150394475, 111: 0.03188795225597549, 112: 0.12816990233288028, 113: 0.10397194009660167, 114: 0.14561356407545042, 115: 0.02035944786407215, 116: 0.15368615878472, 117: 0.10683678198781524, 118: 0.08341370766804634, 119: 0.07475672765518968, 120: 0.061363535270458555, 121: 0.10754095478025102, 122: 0.19258102845784114, 123: 0.05553157893572032, 124: 0.15224065573415801, 125: 0.059121442797684345, 126: 0.12189225629680574, 127: 0.15670064855008636, 128: 0.09923639825634478, 129: 0.12354553962334411, 130: 0.14634300565673766, 131: 0.2023386873089056, 132: 0.17129119043480634, 133: 0.10557187608803184, 134: 0.15241416975159142, 135: 0.08402680887872417, 136: 0.0834446863654507, 137: 0.12657958569737301, 138: 0.003596770948880057, 139: 0.09456912607961532, 140: 0.19136874034526785, 141: 0.12128422865260825, 142: 0.009186921440029874, 143: 0.09166288170340536, 144: 0.007579152506385897, 145: 0.09338413830763602, 146: 0.17253980979154387, 147: 0.13234021068369123, 148: 0.07805221822736669, 149: 0.10670587737264456, 150: 0.11431385632379407, 151: 0.09086102164689945, 152: 0.08035039132818843, 153: 0.023892128275944086, 154: 0.1813207417263592, 155: 0.030199848878420504, 156: 0.15117466066355745, 157: 0.13033 ...

# %% [markdown]
# ## Part 3: Rumor Spreading on Hypergraph
# The follow steps extends the basic rumor spreading model to a hypergraph. An infection or recovery event can only happen if its infected or recovered neighbors reach a pre-assigned threshold.

# %%
def rumor_hyperedge_3(nw, ldeg, mu, lam, alp, n_samp):
    t_max = 10000
    N = nw.order()
    kmax = max(ldeg)
    sigma = 0
    ltre = assign_thresholds(nw)

    t_end = 0
    stifler_fractions = []

    for i_samp in range(1, n_samp+1):
        t = 0
        N_rec = 0

        states = {j: 0 for j in nw.nodes()}

        inf = []
        rec = []
        initial_node = np.random.choice(list(nw.nodes()))
        states[initial_node] = 1
        inf.append(initial_node)
        N_inf = 1
        N_e = nw.degree(initial_node)

        while N_inf != 0:
            total_rate = lam * N_e + 2 * alp * N_e
            tau = -np.log(np.random.uniform(1e-6, 1)) / total_rate
            t += tau

            if t >= t_max:
                break

            #print("Current time:", t)
            #print("Infected nodes:", inf)
            #print("Recovered nodes:", rec)
            #print("N_inf:", N_inf)
            #print("N_e:", N_e)
            #plt.figure()
            #plot_hypergraph(H, states)

            # Determine which event occurs
            event = np.random.uniform()
            p1 = lam / (lam + 2 * alp)
            p2 = (lam + alp )/ (lam + 2 * alp)

            # Determine if accept selected spreader based on degree distribution
            q_deg = np.random.uniform()


            # Infection:
            if event <= p1:
                # Select a spreader individual to spread the rumor
                inf_node = random.choice(inf)
                if q_deg < ldeg[inf_node] / kmax:
                    # Select a random hyper edge containing the infected node
                    infected_hyper_edge = np.random.choice(list(nw.edges()))
                    neighbors = nw[infected_hyper_edge]
                    while inf_node not in neighbors:
                        infected_hyper_edge = np.random.choice(list(nw.edges()))
                        neighbors = nw[infected_hyper_edge]

                    # Check if any neighbor meets the infection threshold
                    for neighbor in neighbors:
                        # Check if the selected neighbor is ignorant
                            if states[neighbor] == 0:
                                #print("Infection event")
                            # Check the threshold
                                count_inf_neighbors = sum(states[node] == 1 for node in nw.neighbors(neighbor))
                                if count_inf_neighbors / len(nw.neighbors(neighbor)) >= ltre[neighbor]:
                                    states[neighbor] = 1  # ignorant neighbor becomes spreader
                                    inf.append(neighbor)
                                    N_inf += 1
                                    #print("successful infection")


            else:  # Recovery
                # Select a spreader individual to recover
                rec_node = np.random.choice(inf)
                if q_deg < ldeg[rec_node] / kmax:
                    # Select a random hyperedge containing the recovered node
                    recovered_hyper_edge = np.random.choice(list(nw.edges()))
                    # Get neighbors list
                    neighbors = nw[recovered_hyper_edge]
                    #print("Recovery event", neighbors)
                    if event <=p2:
                        count_rec_neighbors = sum(states[node] == 2 for node in neighbors)
                        #print("count_rec_neighbors", count_rec_neighbors)
                        if count_rec_neighbors / len(neighbors) >= ltre[rec_node]:
                        #if count_rec_neighbors > 0:
                            # Update spreader to stifler if the selected neighbor is a stifler or spreader
                            states[rec_node] = 2
                            N_inf -= 1
                            inf.remove(rec_node)
                            rec.append(rec_node)
                            N_rec += 1
                            #print("successful recovery")

                    else:
                        count_rec_neighbors = sum(states[node] == 1 for node in neighbors)
                        #print("count_rec_neighbors", count_rec_neighbors)
                        if count_rec_neighbors / len(neighbors) >= ltre[rec_node]:
                        #if count_rec_neighbors > 0:
                            # Update spreader to stifler if the selected neighbor is a stifler or spreader
                            states[rec_node] = 2
                            N_inf -= 1
                            inf.remove(rec_node)
                            rec.append(rec_node)
                            N_rec += 1
                            #print("successful recovery")

                    """
                    else:
                        for neighbor in neighbors:
                        # Check the threshold of infected
                            count_inf_neighbors = 0
                            for node in neighbors:
                                if states[node] == 1:
                                    count_inf_neighbors += 1
                            if count_inf_neighbors / len(neighbors) >= Ltre[rec_node]:
                                # Update spreader to stifler if the selected neighbor is a stifler
                                states[rec_node] = 2
                                N_inf -= 1
                                N_e -= nw.degree(rec_node)
                                inf.remove(rec_node)
                                rec.append(rec_node)
                                N_rec += 1
                    """
            #print("N_inf after event:", N_inf)
            #print("N_e after event:", N_e)


        if N_inf == 0:
              t_end += t
              stifler_frac = N_rec / N
              stifler_fractions.append(stifler_frac)
              print("Sampling result - Lam:", lam, "N_rec:", N_rec, "t_end:", t_end, "stifler_frac:", stifler_frac)

    avg_stifler_frac = sum(stifler_fractions) / len(stifler_fractions)
    t_end_av = t_end/n_samp

    #return nw, states
    return avg_stifler_frac, t_end_av

# %% [markdown]
# The following function generates the hypergraph based on nodes' disease status, where susceptible nodes are yellow, infected nodes are purple, and recovered nodes are green.

# %%
def plot_hypergraph(hypergraph, states):
    pos = nx.spring_layout(hypergraph)
    node_colors = []
    #node_sizes = []
    for node in hypergraph.nodes():
        if states[node] == 1:  # Infected node (purple)
            node_colors.append("purple")
        elif states[node] == 2:  # Recovered node (green)
            node_colors.append("green")
        else:  # Susceptible node (yellow)
            node_colors.append("yellow")
        #node_sizes.append(thresholds[node] * 100)  # Adjust node size based on threshold value

    hnx.drawing.draw(hypergraph, pos, nodes_kwargs={'facecolors': node_colors})

# %%
n_samp = 100
alp = 1

# Set the mu and lambda_values
mu_values = np.arange(0.0, 0.1, 0.1)
lambda_values = np.arange(0.1, 1.0, 0.1)

# Initialize the result array
results = np.zeros((len(mu_values), len(lambda_values)))

# Iterate over mu and lambda values
for i, mu in enumerate(mu_values):
    for j, lam in enumerate(lambda_values):
        rho_R_av, t_end_av = rumor_hyperedge_3(H2, degrees2, mu, lam, alp, n_samp)
        results[i, j] = rho_R_av
# Out:
# Sampling result - Lam: 0.1 N_rec: 371 t_end: 355.10017459232097 stifler_frac: 0.9275
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 368.92849590979733 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 381 t_end: 781.3137907113912 stifler_frac: 0.9525
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 1156.8977247704834 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 1163.1436589094867 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 1554.9043520583703 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 390 t_end: 1958.5892114529956 stifler_frac: 0.975
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 2366.913330959746 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 2389.7499085112277 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 327 t_end: 2713.810277547835 stifler_frac: 0.8175
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 3085.3660140034426 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 3104.0132150789136 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 363 t_end: 3432.0140395409144 stifler_frac: 0.9075
# Sampling result - Lam: 0.1 N_rec: 384 t_end: 3861.276773284356 stifler_frac: 0.96
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 4214.8371932055215 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 326 t_end: 4525.418257193735 stifler_frac: 0.815
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 4984.9193258911055 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 5436.931368124292 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 5812.242995204155 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 6204.956126208068 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 400 t_end: 6634.487770077172 stifler_frac: 1.0
# Sampling result - Lam: 0.1 N_rec: 366 t_end: 6997.768365356925 stifler_frac: 0.915
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 7591.707061467017 stifler_frac: 0.97
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 8007.463462428758 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 8007.622796151544 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 8474.156005010553 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 8856.231815757006 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 9250.35753528446 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 377 t_end: 9380.260024288256 stifler_frac: 0.9425
# Sampling result - Lam: 0.1 N_rec: 56 t_end: 9528.088874352443 stifler_frac: 0.14
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 10144.579296464792 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 10602.100201689407 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 10835.946931136636 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 363 t_end: 11318.046932256188 stifler_frac: 0.9075
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 11594.314390920872 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 347 t_end: 11990.71531775251 stifler_frac: 0.8675
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 12381.509328781878 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 399 t_end: 12682.541648876195 stifler_frac: 0.9975
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 13085.19611254891 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 13085.332990466644 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 13499.401913217953 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 13635.730807076054 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 371 t_end: 14011.846443962915 stifler_frac: 0.9275
# Sampling result - Lam: 0.1 N_rec: 377 t_end: 14390.554270945655 stifler_frac: 0.9425
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 14533.25202148899 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 14940.64436716347 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 399 t_end: 15369.050804415961 stifler_frac: 0.9975
# Sampling result - Lam: 0.1 N_rec: 381 t_end: 15720.86554929318 stifler_frac: 0.9525
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 16134.029247274932 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 16536.096139485577 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 16941.740198901512 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 16948.061618524316 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 16951.052224986273 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 357 t_end: 17304.30068790895 stifler_frac: 0.8925
# Sampling result - Lam: 0.1 N_rec: 384 t_end: 17602.34966172676 stifler_frac: 0.96
# Sampling result - Lam: 0.1 N_rec: 390 t_end: 18046.325632509688 stifler_frac: 0.975
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 18436.68456387514 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 18438.39435562041 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 375 t_end: 18808.086886326768 stifler_frac: 0.9375
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 18819.05027143828 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 19220.178692113735 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 19662.824637385926 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 20285.204195237875 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 386 t_end: 20716.9855450659 stifler_frac: 0.965
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 20720.46855400461 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 21168.21831912165 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 21594.896719901313 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 387 t_end: 22012.695560725886 stifler_frac: 0.9675
# Sampling result - Lam: 0.1 N_rec: 381 t_end: 22386.94375070917 stifler_frac: 0.9525
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 22845.959908906894 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 22857.491997652734 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 23290.892454398723 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 390 t_end: 23703.708733227588 stifler_frac: 0.975
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 23919.025440405912 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 24318.282231392794 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 373 t_end: 24692.605885589266 stifler_frac: 0.9325
# Sampling result - Lam: 0.1 N_rec: 399 t_end: 25134.318241948993 stifler_frac: 0.9975
# Sampling result - Lam: 0.1 N_rec: 377 t_end: 25663.480813279813 stifler_frac: 0.9425
# Sampling result - Lam: 0.1 N_rec: 399 t_end: 25874.078945243178 stifler_frac: 0.9975
# Sampling result - Lam: 0.1 N_rec: 348 t_end: 26240.99818668524 stifler_frac: 0.87
# Sampling result - Lam: 0.1 N_rec: 381 t_end: 26631.006667384518 stifler_frac: 0.9525
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 27119.97330940798 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 27148.179338667578 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 27161.32551769831 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 376 t_end: 27602.58683787133 stifler_frac: 0.94
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 28051.93955247837 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 28393.970166485622 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 381 t_end: 28798.07700083753 stifler_frac: 0.9525
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 29131.47992261627 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 29543.291927899856 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 29965.87077064393 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 382 t_end: 30318.208759482608 stifler_frac: 0.955
# Sampling result - Lam: 0.1 N_rec: 372 t_end: 30756.042104857766 stifler_frac: 0.93
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 31147.015092276404 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 31525.038997122116 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 361 t_end: 31925.04225655968 stifler_frac: 0.9025
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 32358.96290455577 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 32398.19932122216 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 32398.3796045737 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 32675.486961456903 stifler_frac: 0.97
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 385.4268963739885 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 830.4212180669151 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 1278.1303112098026 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1438.8272250322113 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1882.4881059297347 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 2309.9617449726557 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 395 t_end: 2685.1067418309585 stifler_frac: 0.9875
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 3104.5761140223576 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 3482.4554092891567 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 3867.9575719273853 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 4025.3182918599327 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 4403.886964759329 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 4809.972410692732 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 5221.626754299752 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 5610.039186034171 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 6030.982094182957 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 6237.726872168157 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 6659.922214664321 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 395 t_end: 7306.065587764426 stifler_frac: 0.9875
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 7306.2995922010805 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 7734.818501474838 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 7739.827062576337 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 8137.213307451985 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 393 t_end: 8535.370769266052 stifler_frac: 0.9825
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 8952.985899199695 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 9351.934893240877 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 9732.240177159983 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 10174.740779490663 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 10576.277264520562 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 10961.218826671598 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 11353.274567170753 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 11586.886495651128 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 11997.448298550631 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 12290.921264319471 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 12687.9282568472 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 13092.809259870884 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 13271.417033888143 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 13680.387413729528 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 14047.671088583562 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 14433.978755180045 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 14856.593668192432 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 15238.895133275368 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 15634.844406329488 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 16047.601263922903 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 16433.484073994692 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 16832.404909148976 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 17233.355936941036 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 17594.662587166444 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 17990.104781189195 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 18285.826688268695 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 18298.158839920503 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 18736.504388634417 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 19145.85713927216 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 19320.388542408382 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 19764.893762037245 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 20190.803897978596 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 20632.18876672197 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 21260.342398686076 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 21647.956106866688 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 22053.226731433966 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 22080.569716348255 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 22445.4494526273 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 22856.99441955508 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 23276.204943237357 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 23681.42647493332 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 24336.926264093745 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 24618.208750194644 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 24997.955596919757 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 25401.4961555398 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 25794.958559285828 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 26170.654217287694 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 26603.721925923008 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 26603.819023490407 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 27025.826841963306 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 27437.912132963665 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 27845.114216349066 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 28233.618557558948 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 28612.88400780923 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 29037.195960621175 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 29476.462405888873 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 29878.292400781545 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 30122.95691655581 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 30515.337056808457 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 30955.756950341372 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 31574.863875486342 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 31981.0159605806 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 32358.040106258926 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 32655.4208022781 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 33046.18065666108 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 33490.04335712811 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 33929.160169098206 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 34329.65361216264 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 34744.326817142784 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 35160.45454542538 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 35560.30644199769 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 36130.75413751197 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 36528.51280817083 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 36926.88109420889 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 37332.592409538694 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 37489.1847497656 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 391.0261318749494 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 842.2809795821418 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1226.3944655486162 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1458.2501805335155 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 1844.4772445838014 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2249.1412487954863 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2704.675482851454 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 2708.9372079795166 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3328.0654927621763 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3693.3869329616045 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 4081.6121096379534 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 4492.153337943429 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 4935.01456852246 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 4935.492334593553 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 5233.130384248268 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5433.87061513533 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 5438.0961381335965 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5887.771549611434 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 6295.717890987869 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 6689.706828798511 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 7316.116459174069 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 7319.555895086309 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 7736.188950982662 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 7737.708715313992 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 8027.14340784772 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 8411.763226272786 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 8833.986812470022 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 9414.942516709425 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 9809.20931042864 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 10012.974783365371 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 10082.801859539835 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 10490.72654346466 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 10889.238108730391 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 11311.604489847488 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 11729.019121011566 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 12115.103900892813 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 12454.096129641954 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 12597.693976626017 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 12999.424831135462 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 13391.721864065701 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 13806.863504126493 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 14211.796719910608 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 14348.374484808159 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 14787.242463754315 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 15195.01154905031 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 15609.538146844152 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 15992.454942537655 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 16396.927821956946 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 16827.39593896271 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 17255.690109591793 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 17411.250412264504 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 17792.960175790875 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 18212.130327051793 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 18607.89661848338 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 18982.5896253295 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 19376.192709153067 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 19769.296825558602 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 19923.9302079591 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 20298.472580207617 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 20677.814873503692 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 21060.027880111982 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 21455.82619699298 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 21859.816683656754 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 21860.610068658956 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 22275.777191176123 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 22695.568540450204 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 23093.626027509035 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 23524.88605484544 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 23908.57053797133 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 396 t_end: 24285.960988037397 stifler_frac: 0.99
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 24292.46703022494 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 24700.74275210164 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 25024.627561416593 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 25412.97239334835 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 25799.45905850914 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 26203.291964055203 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 26622.609857936382 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 27001.392056465047 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 27179.464191889325 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 27615.079281141854 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 27619.359955891363 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 398 t_end: 28010.168857288125 stifler_frac: 0.995
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 28588.504027712257 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 28983.4464774178 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 29439.367825887304 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 29814.374501518487 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 30221.52318754138 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 30376.797776711042 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 30800.826334067733 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 31205.353847932554 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 31610.763023643965 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 32012.085441353975 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 32412.48764590096 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 32827.12196905788 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 32969.6023091824 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 33375.934992988914 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 33757.162208557005 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 34164.19929956395 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 34585.999452211734 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 34976.56313614377 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 395.4561651479286 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 781.0157770966428 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1198.2285525248142 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1592.6082820488607 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1992.5866345204245 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2404.853134792784 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 2405.3948188855397 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2787.404189621548 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3174.6581946959454 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3568.054224719296 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3974.795094987986 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 4378.700892673174 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 4785.290186638487 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5209.3141437675085 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5445.967765444297 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5844.664502172375 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 6243.671259466145 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 6615.051612413449 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 6977.359132086766 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 7390.138978238559 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 7761.618733863276 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 7766.191716534052 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 8190.287395732571 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 8596.632015768126 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 8979.153647973653 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 9381.74487535637 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 9791.798363829012 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 10205.328720188196 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 10605.90125805396 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 11022.05883852225 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 11444.399240367926 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 11801.391592048461 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 11987.052523922244 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 12397.250101108633 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 12796.36454031432 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 12800.538760371046 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 13176.490215080654 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 13413.157588318212 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 13785.30353445207 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 13787.905019001877 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 13990.107281695335 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 14574.153727551478 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 14985.228433301947 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 15391.689863591273 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 15771.010440276268 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 16189.004461284352 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 16609.086690477492 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 17023.875026114678 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 17436.78616756961 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 17875.052600303323 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 18255.091125593746 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 18257.511150938502 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 18693.431074053882 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 19108.276752812082 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 19406.676815900893 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 19805.45104536478 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 20185.227991866963 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 20592.639793310886 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 20971.71014620926 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 21369.752043346856 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 21805.067714704728 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 22188.814112294433 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 22627.697890536372 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 23003.292731766847 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 23419.97950164515 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 23420.896804283533 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 23722.477746966742 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 24119.70780112029 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 24526.163767625727 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 24527.597753043265 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 24746.117971543852 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 25152.07776428812 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 25455.91974475132 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 25837.74935329903 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 26217.578357812035 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 26625.800458838978 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 27017.22196455816 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 27022.04459566519 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 27409.8239900853 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 27838.98896176154 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 28208.019434274873 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 28615.866253479675 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 29063.601623221566 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 29263.227809740514 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 29562.71951198383 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 29947.00857065169 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 30350.3000750172 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 30751.295480225457 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 31160.221232962493 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 31555.241242488984 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 31953.3542819303 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 32371.35559178861 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 32779.12309846013 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 33179.77473209482 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 33580.15551943007 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 33996.65584848776 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 34367.35026434751 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 34769.01427957191 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 35168.739938650426 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 35556.41009375195 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 422.7546968708619 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 822.0695091045793 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 1203.6373148073121 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 1594.6251247905684 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 1596.4146728673256 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 2018.7317810374595 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 2020.0035056527392 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 2374.750781087592 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 2789.0376460056204 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 2789.0484668660856 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 3186.942775252159 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 3195.862110064028 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 3598.5507453314804 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 3838.7879448815843 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 4238.867724101076 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 4613.951257152391 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 5022.34400525347 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 5381.421075934012 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 5760.973886234565 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 6193.247810284978 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 6596.953537451369 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 7006.442700955365 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 7410.49486829223 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 7789.558550926314 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 8204.627840409406 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 8585.285433294199 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 9172.569235619534 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 9596.372240725877 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 10006.954687064599 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 10402.905492970227 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 10655.48789017634 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 11059.099758199058 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 11059.892895496823 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 11454.86231871588 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 11842.733876372708 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 12240.365633149122 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 12657.401956966483 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 13043.847796350883 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 13445.02711830496 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 13822.842627193319 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 14225.668995967073 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 14534.876175530315 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 14534.99113807812 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 14950.438868542447 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 15314.060250251998 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 15575.190990682013 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 15962.536245265326 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 16372.268896628402 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 16667.250768108945 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 17089.099093114844 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 17479.386195727217 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 17874.845837355264 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 18260.378915575824 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 18876.02826556933 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 19292.905057232132 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 19654.13886991991 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 20087.09397569562 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 20505.60611243073 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 20889.551571748925 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 21286.81138629011 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 21705.676472943047 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 22103.791191319928 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 22502.70703793695 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 22906.70941290397 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 23297.348490010798 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 23675.76917531954 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 24104.59423930798 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 24507.832996999834 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 25061.85540925776 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 25458.142756265424 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 25459.324624922097 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 25844.70006243649 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 26155.508856078777 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 26510.694276810405 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 26883.982644219817 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 27273.642000348555 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 27666.755164351336 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 28091.583053552717 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 28333.470713146242 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 28778.41059618591 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 29142.011813264806 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 29563.94895098912 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 29974.75187788047 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 30384.679467730744 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 30764.06904618903 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 31168.785615082827 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 31396.082139182436 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 31545.46251064137 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 31939.169090492687 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 32344.424739745955 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 32766.835361674628 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 33155.704479759945 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 33561.40277018421 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 33988.221966276265 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 34360.30896089836 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 34762.881938937244 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 1 t_end: 34764.558578010656 stifler_frac: 0.0025
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 35159.28767387649 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 35561.56722241313 stifler_frac: 1.0
# Sampling result - Lam: 0.5 N_rec: 400 t_end: 35966.11447592008 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 465.4640545635616 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 561.3485412507426 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 977.7351797387025 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 1347.0578649829429 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 1 t_end: 1347.069196577558 stifler_frac: 0.0025
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 1940.7551987047525 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 2342.0227045496104 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 2745.427129566343 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 1 t_end: 2749.0600929109546 stifler_frac: 0.0025
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 3141.6135950313824 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 1 t_end: 3142.3891042099176 stifler_frac: 0.0025
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 3553.9423289129363 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 3955.7845312748873 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 4321.297118394486 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 4691.7770825052785 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 5261.654133901693 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 5536.148988972351 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 5925.466220601632 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 6331.155729833989 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 6520.621987117369 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 6934.114927527329 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 7284.868542524606 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 7678.027414345344 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 7874.749393842051 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 8076.422174529346 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 8456.63213769955 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 8859.561521215857 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 9095.21207014689 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 9542.859961294875 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 9910.601116315072 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 10278.009449076379 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 10683.171224044068 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 11104.685151977785 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 11529.337232975853 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 11924.605880417063 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 12290.736460850536 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 12662.90486374399 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 13064.071854523636 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 13431.200479966332 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 13782.495993982018 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 14079.45807006343 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 14391.708221816913 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 14768.526223308016 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 15152.344936033625 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 15530.947806417764 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 15938.31365984161 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 16330.19582855679 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 16714.655775406518 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 17117.04740140167 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 17536.501599881423 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 17953.80242658756 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 18337.83721552528 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 18568.664048222614 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 18945.57743988531 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 19341.263599398644 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 19997.21590711748 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 20408.36177422135 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 20776.24881085169 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 21038.628560101602 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 21240.194800448946 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 21640.30228968534 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 22041.21306839137 stifler_frac: 1.0
# Sampling result - Lam: 0.6 N_rec: 400 t_end: 22221.789505024608 stifler_frac: 1.0
# ...
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 1672.7321943086704 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 2058.7464094595725 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 2431.24247395484 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 2826.6740178552727 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 3225.1187794903817 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 3609.080504721758 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 3976.000862967306 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 3977.6834472459877 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 4368.986359141764 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 4741.31677931212 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 5137.601505924141 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 5541.699108010017 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 6134.995069326997 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 6524.002152350931 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 6945.209929330452 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 7312.675218307106 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 7655.5851710226525 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 8024.511117081447 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 8409.772837912713 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 8822.134446396625 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 9240.362819478114 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 9663.982080193366 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 10049.295258420472 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 10480.009173861128 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 10892.238107083247 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 11330.777800913926 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 11709.990896678546 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 12110.45303451097 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 12516.327986876262 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 12935.533544857779 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 1 t_end: 12936.278376441476 stifler_frac: 0.0025
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 13292.750330829751 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 13705.057702793076 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 14116.513335207605 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 14489.450285369787 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 14873.952707218243 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 15270.77380474198 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 15614.535060632506 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 15755.398567093616 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 16150.429234146904 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 16525.793394427532 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 16766.44061467999 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 17192.17248336593 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 17547.190616498814 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 18170.27263901822 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 18569.404230979115 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 18979.117073467984 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 19375.10657803335 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 19774.985981538448 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 20187.58762427933 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 20487.16412482082 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 20726.503806318357 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 21119.203766938637 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 21398.409174377444 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 21797.115660459593 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 22175.150923779343 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 22810.847770469954 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 23275.16951228236 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 23366.537038226856 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 23787.427716992534 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 23892.268497408033 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 24318.52021159538 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 24707.490618147705 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 25118.584983453788 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 25526.66183919331 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 25789.721054424725 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 26218.418085219073 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 26590.010588127618 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 26898.859913465163 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 27464.075669808917 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 27878.726947227035 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 28233.334789197794 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 28639.95663848981 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 28714.670148286838 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 29334.95717942879 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 29620.335381684792 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 30054.71755081664 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 30483.78083517436 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 30597.84208948187 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 30994.403731320825 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 31383.24666545715 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 31795.428438335657 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 32175.88469616442 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 32615.88869824452 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 33029.88571524221 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 33427.9798110258 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 33803.53911182915 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 34200.88353804762 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 34588.60955148528 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 34938.23422567332 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 35311.877864323156 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 35682.14553079547 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 35838.07768977286 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 36274.0739284742 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 36656.22822066181 stifler_frac: 1.0
# Sampling result - Lam: 0.8 N_rec: 400 t_end: 37049.163960944185 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 373.78934503996527 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 636.4103330151222 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 1016.3798489453258 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 1409.563697290891 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 1805.9436610204534 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 1806.013062097176 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 2427.2108403422544 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 2622.324588304962 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 3000.7926531881 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 3386.120014384681 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 3679.781174598008 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 4088.927955690739 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 4508.807812376533 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 4906.719230291139 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 5276.663095873475 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 5702.210174599768 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 6126.412920685509 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 6530.624546061135 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 6951.394026457969 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 7162.914531422794 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 7549.6968464898855 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 7952.626344166035 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 8342.321954613733 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 8730.882616536794 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 9104.258392114569 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 9273.305698173283 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 9669.82982013217 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 10054.712733404793 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 10451.921159209889 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 10853.205930402126 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 10856.47793277766 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 11262.946209283273 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 11577.159831365458 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 11977.198574954473 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 12536.643511492846 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 12926.145771805224 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 13323.16592719937 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 13718.308439389853 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 14101.409286500984 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 14474.62987958738 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 14881.643222994202 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 15262.738555693208 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 15641.371500361296 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 16073.268026154421 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 16358.115619615131 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 16781.579182826863 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 17202.20092432284 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 17603.1352050011 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 17908.95348814514 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 18319.668093266646 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 18624.130849597666 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 19012.421741187838 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 19391.384879223093 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 19697.12389579058 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 20072.362117396635 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 20380.523667521764 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 20382.122907039655 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 20754.85688300769 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 21131.771780284587 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 21551.189524652043 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 21952.016339970596 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 22330.31543062562 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 22410.997498727145 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 22616.443672288424 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 23029.41085708412 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 23588.957366777184 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 24002.584360178116 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 24389.33344365252 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 24771.038345194283 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 25170.02616818762 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 25554.580413437052 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 25973.050060950944 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 26099.621787721288 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 26496.8427006434 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 26891.848581252594 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 27268.858280707696 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 27272.90775016854 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 27545.532065494717 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 27945.546321212067 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 28337.386073209305 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 28736.734807887155 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 29148.494962360557 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 29551.196779517082 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 29934.507833179276 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 30357.69009574837 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 30746.920138759084 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 30819.73354152394 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 31107.905433156113 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 31510.382530578132 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 31898.858328152633 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 32310.46959964393 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 32739.434684270083 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 1 t_end: 32739.74327007437 stifler_frac: 0.0025
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 33118.95454440806 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 33538.733839244866 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 33773.27744692476 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 34145.24911874344 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 34547.98550955504 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 34913.285500003294 stifler_frac: 1.0
# Sampling result - Lam: 0.9 N_rec: 400 t_end: 35285.305763848824 stifler_frac: 1.0

# %%
import matplotlib.ticker as ticker

# Plot the heat map
fig, ax = plt.subplots(figsize=(8, 6))
heatmap = ax.imshow(results, cmap='YlGnBu', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(lambda_values)))
ax.set_yticks(np.arange(len(mu_values)))

# Format the tick labels with two decimal places using string formatting
lambda_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
mu_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(lambda_formatter)
ax.yaxis.set_major_formatter(mu_formatter)

ax.set_xticklabels(['{:.2f}'.format(val) for val in lambda_values])
ax.set_yticklabels(['{:.2f}'.format(val) for val in mu_values])
plt.xticks(rotation=45)
plt.colorbar(heatmap)

# Set labels and title
ax.set_xlabel('Rate of Misinformation Spread ($\lambda$)')
ax.set_ylabel('Average Information Acceptance Threshold ($\mu$)')
ax.set_title('Average Stifler Density Heatmap (Hyperedge Group Spread)')

# Display the heat map
plt.show()
