# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancy-Shi/Complex_Networks/blob/main/Updated_Hypergraph_Models_071323.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import random
import math as math
from math import log
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Part 1: Hypergraph Generation
# The following steps generate a hyper graph using the XGI/HyperNetX python package,  following power-law degree distribution for predifined number of nodes n, number of hyperedges num_hyper_edges, degree exponent gamma, using a configuration model with data stored in a dictionary.

# %%
# Step 1: Generate Degree Sequence
def generate_degree_sequence(n, gamma, kmin):
    # Generate a random set from the power law distribution
    u = np.random.uniform(size=n)
    degrees = np.ceil((1.0 - u) ** (-1.0 / (gamma - 1.0)))

    # Adjust degrees based on the minimum and maximum degree values
    kmax = int(np.sqrt(n))
    # kmax = int(1.5*n**(1/4)) # max degree allowed is 1.5*n^(1/4)
    degrees = degrees[(degrees >= kmin) & (degrees <= kmax)].astype(int)

    # Truncate or pad the sequence to match the length specified
    if len(degrees) >= n:
        degrees = degrees[:n]
    else:
        degrees = np.concatenate((degrees, np.full(n - len(degrees), kmin)))

    return degrees.tolist()

# Step 2: Generate Hyper Edge Size Sequence
def generate_hyper_edge_sizes(degrees, num_hyper_edges):
    total_degrees = sum(degrees)
    hyper_edge_sizes = []

    # Calculate the average size for each hyper edge
    avg_size = total_degrees // num_hyper_edges
    remainder = total_degrees % num_hyper_edges

    # Define the range for the random distribution
    min_size = 1  # Lower bound of the range
    max_size = len(degrees)-num_hyper_edges  # Upper bound of the range

    # Generate hyper edge sizes
    for _ in range(num_hyper_edges):
        size = random.randint(min_size, max_size)
        hyper_edge_sizes.append(size)

    return hyper_edge_sizes


# Step 3: Create Copies of Nodes
def create_node_copies(degrees):
    node_copies = []
    for i, degree in enumerate(degrees):
        for _ in range(degree):
            node_copies.append(i)
    return node_copies

# Step 4: Create Copies of Hyper Edges
def create_hyper_edge_copies(hyper_edge_sizes):
    hyper_edge_copies = []
    for i, size in enumerate(hyper_edge_sizes):
        for _ in range(size):
            hyper_edge_copies.append(i)
    return hyper_edge_copies

# Step 5: Randomly Pair Copies
def randomly_pair_copies(node_copies, hyper_edge_copies):
    random.shuffle(node_copies)
    random.shuffle(hyper_edge_copies)
    pairs = []
    for i in range(len(node_copies)):
        pairs.append((node_copies[i], hyper_edge_copies[i]))
    return pairs

# Step 6: Convert Bipartite Graph to A Hypergraph Dictionary
def convert_to_hypergraph(pairs):
    hypergraph = {}
    for pair in pairs:
        node, hyper_edge = pair
        if hyper_edge in hypergraph:
            hypergraph[hyper_edge].append(node)
        else:
            hypergraph[hyper_edge] = [node]
    return hypergraph

# %%
def build_hypergraph(n, gamma, kmin, num_hyper_edges):
    # Step 1: Generate Degree Sequence
    degrees = generate_degree_sequence(n, gamma, kmin)
    print("Degree Sequence: ", degrees)

    # Step 2: Generate Hyper Edge Size Sequence
    hyper_edge_sizes = generate_hyper_edge_sizes(degrees, num_hyper_edges)
    print("Hyper Edge Sizes: ", hyper_edge_sizes)

    # Step 3: Create Copies of Nodes
    node_copies = create_node_copies(degrees)

    # Step 4: Create Copies of Hyper Edges
    hyper_edge_copies = create_hyper_edge_copies(hyper_edge_sizes)

    # Step 5: Randomly Pair Copies
    pairs = randomly_pair_copies(node_copies, hyper_edge_copies)

    # Step 6: Convert Bipartite Graph to Hypergraph
    hyperedge_dict = convert_to_hypergraph(pairs)

    # Print the resulting hypergraph
    print("Hypergraph Dictionary: ", hyperedge_dict)

    return degrees, hyperedge_dict

# %%
# !pip install hypernetx
import hypernetx as hnx
# Out:
# Collecting hypernetx
#   Downloading hypernetx-2.0.2-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.5/95.5 kB 10.1 MB/s eta 0:00:00
# Collecting networkx<3.0,>=2.2 (from hypernetx)
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.8 MB/s eta 0:00:00
# Collecting numpy<2.0,>=1.24.0 (from hypernetx)
#   Downloading numpy-1.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.10.1)
# Requirement already satisfied: matplotlib>3.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.2.2)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.5.3)
# Collecting decorator>=5.1.1 (from hypernetx)
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>3.0->hypernetx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->hypernetx) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->hypernetx) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->hypernetx) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>3.0->hypernetx) (1.16.0)
# Installing collected packages: numpy, networkx, decorator, hypernetx
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.1 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.1 which is incompatible.
# Successfully installed decorator-5.1.1 hypernetx-2.0.2 networkx-2.8.8 numpy-1.25.1
#  No module named 'igraph'. If you need to use hypernetx.algorithms.hypergraph_modularity, please install additional packages by running the following command: pip install .['all']

# %%
# Test 1
n =50  # Number of nodes
gamma = 2.5  # Power-law exponent
kmin = 3  # Minimum degree
num_hyper_edges = 8  # Desired number of hyper edges

degrees, hyperedge_dict = build_hypergraph(n, gamma, kmin, num_hyper_edges)
# Plot the hypergraph
H = hnx.Hypergraph(hyperedge_dict)
plt.subplots(figsize=(5,5))
hnx.draw(H)
# Out:
# Degree Sequence:  [3, 4, 6, 3, 3, 3, 7, 4, 3, 3, 3, 5, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [16, 26, 40, 37, 19, 21, 33, 32]
# Hypergraph Dictionary:  {6: [34, 7, 36, 23, 21, 31, 1, 29, 5, 41, 21, 49, 49, 37, 15, 15, 14, 2, 29, 24, 32, 18, 47], 3: [13, 22, 32, 25, 5, 18, 4, 26, 27, 1, 30, 38, 25, 8, 43, 20, 44, 39, 37, 43, 12, 12, 6, 30, 42, 10], 2: [27, 44, 42, 9, 2, 11, 48, 35, 38, 14, 48, 20, 48, 46, 31, 2, 6, 17, 34, 6, 35, 10, 40, 13, 39, 36, 7, 9, 16], 1: [9, 0, 27, 28, 2, 7, 16, 22, 46, 41, 41, 45, 22, 39, 49, 29, 23, 19, 33], 4: [3, 13, 2, 34, 0, 6, 25, 26, 23, 45, 12, 6, 30, 24], 7: [47, 21, 7, 17, 46, 31, 36, 4, 45, 33, 12, 4, 16, 1, 3, 10, 14, 47, 32, 2, 17, 43, 28, 19, 15, 24, 11, 42], 5: [19, 11, 6, 38, 18, 20, 0, 1, 3, 33, 40, 28, 26], 0: [35, 6, 40, 11, 37, 8, 44, 11, 5, 8]}

# %%
# Test 2
n2 =400  # Number of nodes
gamma2 = 2.5  # Power-law exponent
kmin2 = 3  # Minimum degree
num_hyper_edges2 = 100  # Desired number of hyper edges

degrees2, hyperedge_dict2 = build_hypergraph(n2, gamma2, kmin2, num_hyper_edges2)
H2 = hnx.Hypergraph(hyperedge_dict2)
# Out:
# Degree Sequence:  
# %% [markdown]
# ## Part 3: Rumor Spreading on Hypergraph
# The follow steps extends the basic rumor spreading model to a hypergraph. An infection or recovery event can only happen if its infected or recovered neighbors reach a pre-assigned threshold.

# %%
def rumor_hyperedge_2(nw, ldeg, mu, lam, alp, n_samp):
    t_max = 10000
    N = nw.order()
    kmax = max(ldeg)
    sigma = 0.05
    ltre = assign_thresholds(nw)

    t_end = 0
    stifler_fractions = []

    for i_samp in range(1, n_samp+1):
        t = 0
        N_rec = 0

        states = {j: 0 for j in nw.nodes()}

        inf = []
        rec = []
        initial_node = np.random.choice(list(nw.nodes()))
        states[initial_node] = 1
        inf.append(initial_node)
        N_inf = 1
        N_e = nw.degree(initial_node)

        while N_inf != 0:
            total_rate = lam * N_e + 2 * alp * N_e
            tau = -np.log(np.random.uniform(1e-6, 1)) / total_rate
            t += tau

            if t >= t_max:
                break

            #print("Current time:", t)
            #print("Infected nodes:", inf)
            #print("Recovered nodes:", rec)
            #print("N_inf:", N_inf)
            #print("N_e:", N_e)
            #plt.figure()
            #plot_hypergraph(H, states)

            # Determine which event occurs
            event = np.random.uniform()
            p1 = lam / (lam + 2 * alp)
            p2 = (lam + alp )/ (lam + 2 * alp)

            # Determine if accept selected spreader based on degree distribution
            q_deg = np.random.uniform()


            # Infection:
            if event <= p1:
                # Select a spreader individual to spread the rumor
                inf_node = random.choice(inf)
                if q_deg < ldeg[inf_node] / kmax:
                    # Select a random hyper edge containing the infected node
                    infected_hyper_edge = np.random.choice(list(nw.edges()))
                    neighbors = nw[infected_hyper_edge]
                    while inf_node not in neighbors:
                        infected_hyper_edge = np.random.choice(list(nw.edges()))
                        neighbors = nw[infected_hyper_edge]

                    # Check if any neighbor meets the infection threshold
                    for neighbor in neighbors:
                        # Check if the selected neighbor is ignorant
                            if states[neighbor] == 0:
                                #print("Infection event")
                            # Check the threshold
                                count_inf_neighbors = sum(states[node] == 1 for node in nw.neighbors(neighbor))
                                if count_inf_neighbors / len(nw.neighbors(neighbor)) >= ltre[neighbor]:
                                    states[neighbor] = 1  # ignorant neighbor becomes spreader
                                    inf.append(neighbor)
                                    N_inf += 1
                                    #print("successful infection")


            else:  # Recovery
                # Select a spreader individual to recover
                rec_node = np.random.choice(inf)
                if q_deg < ldeg[rec_node] / kmax:
                    # Select a random hyperedge containing the recovered node
                    recovered_hyper_edge = np.random.choice(list(nw.edges()))
                    # Get neighbors list
                    neighbors = nw[recovered_hyper_edge]
                    #print("Recovery event", neighbors)
                    if event <=p2:
                        count_rec_neighbors = sum(states[node] == 2 for node in neighbors)
                        #print("count_rec_neighbors", count_rec_neighbors)
                        if count_rec_neighbors / len(neighbors) >= ltre[rec_node]:
                        #if count_rec_neighbors > 0:
                            # Update spreader to stifler if the selected neighbor is a stifler or spreader
                            states[rec_node] = 2
                            N_inf -= 1
                            inf.remove(rec_node)
                            rec.append(rec_node)
                            N_rec += 1
                            #print("successful recovery")

                    else:
                        count_rec_neighbors = sum(states[node] == 1 for node in neighbors)
                        #print("count_rec_neighbors", count_rec_neighbors)
                        if count_rec_neighbors / len(neighbors) >= ltre[rec_node]:
                        #if count_rec_neighbors > 0:
                            # Update spreader to stifler if the selected neighbor is a stifler or spreader
                            states[rec_node] = 2
                            N_inf -= 1
                            inf.remove(rec_node)
                            rec.append(rec_node)
                            N_rec += 1
                            #print("successful recovery")

                    """
                    else:
                        for neighbor in neighbors:
                        # Check the threshold of infected
                            count_inf_neighbors = 0
                            for node in neighbors:
                                if states[node] == 1:
                                    count_inf_neighbors += 1
                            if count_inf_neighbors / len(neighbors) >= Ltre[rec_node]:
                                # Update spreader to stifler if the selected neighbor is a stifler
                                states[rec_node] = 2
                                N_inf -= 1
                                N_e -= nw.degree(rec_node)
                                inf.remove(rec_node)
                                rec.append(rec_node)
                                N_rec += 1
                    """
            #print("N_inf after event:", N_inf)
            #print("N_e after event:", N_e)


        if N_inf == 0:
              t_end += t
              stifler_frac = N_rec / N
              stifler_fractions.append(stifler_frac)
              print("Sampling result - Lam:", lam, "N_rec:", N_rec, "t_end:", t_end, "stifler_frac:", stifler_frac)

    avg_stifler_frac = sum(stifler_fractions) / len(stifler_fractions)
    t_end_av = t_end/n_samp

    #return nw, states
    return avg_stifler_frac, t_end_av

# %% [markdown]
# The following function generates the hypergraph based on nodes' disease status, where susceptible nodes are yellow, infected nodes are purple, and recovered nodes are green.

# %%
def plot_hypergraph(hypergraph, states):
    pos = nx.spring_layout(hypergraph)
    node_colors = []
    #node_sizes = []
    for node in hypergraph.nodes():
        if states[node] == 1:  # Infected node (purple)
            node_colors.append("purple")
        elif states[node] == 2:  # Recovered node (green)
            node_colors.append("green")
        else:  # Susceptible node (yellow)
            node_colors.append("yellow")
        #node_sizes.append(thresholds[node] * 100)  # Adjust node size based on threshold value

    hnx.drawing.draw(hypergraph, pos, nodes_kwargs={'facecolors': node_colors})

# %%
n_samp = 20
alp = 1

# Set the mu and lambda_values
mu_values = np.arange(0.0, 0.15, 0.05)
lambda_values = np.arange(0.1, 0.5, 0.1)

# Initialize the result array
results = np.zeros((len(mu_values), len(lambda_values)))

# Iterate over mu and lambda values
for i, mu in enumerate(mu_values):
    for j, lam in enumerate(lambda_values):
        rho_R_av, t_end_av = rumor_hyperedge_2(H3, degrees3, mu, lam, alp, n_samp)
        results[i, j] = rho_R_av

import matplotlib.ticker as ticker

# Plot the heat map
fig, ax = plt.subplots(figsize=(8, 6))
heatmap = ax.imshow(results, cmap='YlGnBu', interpolation='nearest')

# Set the tick labels and show colorbar
ax.set_xticks(np.arange(len(lambda_values)))
ax.set_yticks(np.arange(len(mu_values)))

# Format the tick labels with two decimal places using string formatting
lambda_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
mu_formatter = ticker.StrMethodFormatter('{:.2f}'.format)
ax.xaxis.set_major_formatter(lambda_formatter)
ax.yaxis.set_major_formatter(mu_formatter)
#ax.invert_yaxis()

ax.set_xticklabels(['{:.2f}'.format(val) for val in lambda_values])
ax.set_yticklabels(['{:.2f}'.format(val) for val in mu_values])
plt.xticks(rotation=45)
plt.colorbar(heatmap)

# Set labels and title
ax.set_xlabel('Lambda')
ax.set_ylabel('Mu')
ax.set_title('Average Stifler Density Heatmap')

# Display the heat map
plt.show()
# Out:
# Sampling result - Lam: 0.1 N_rec: 399 t_end: 366.856353914761 stifler_frac: 0.9975
# Sampling result - Lam: 0.1 N_rec: 395 t_end: 435.37592434375364 stifler_frac: 0.9875
# Sampling result - Lam: 0.1 N_rec: 371 t_end: 865.0839847570442 stifler_frac: 0.9275
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 866.8630574609454 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 393 t_end: 1172.799415472945 stifler_frac: 0.9825
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 1549.407560992718 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 1553.9056195533478 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 1719.0790819118347 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 1719.2775591257466 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 2083.723265230976 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 379 t_end: 2449.63479464408 stifler_frac: 0.9475
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 2887.2019471137933 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 379 t_end: 3299.613242791715 stifler_frac: 0.9475
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 3310.259124109594 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 3731.10238797671 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 400 t_end: 3939.3610079972955 stifler_frac: 1.0
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 4179.026885808929 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 4181.687872375758 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 397 t_end: 4568.11211635402 stifler_frac: 0.9925
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 4948.782073492892 stifler_frac: 0.98
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 366.26320939792856 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 397 t_end: 772.8981056291007 stifler_frac: 0.9925
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1163.9966261094207 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 1268.7239117929337 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1674.818519129079 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 2007.6345476904946 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 2026.519352824882 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 2434.2290466018217 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 2802.3517895567684 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 2804.1652475480164 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 2804.844355041553 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 3093.311095424826 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 3485.0526953903645 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 3485.5632237672435 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 3857.2010105978757 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 3864.8277368876807 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 4183.073591836954 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 4187.351491520642 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 4609.821176894014 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 4912.302554163891 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 402.6140234523756 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 779.2519870509416 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1145.0816934302716 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1556.2000027606957 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 1562.4170554320099 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1934.1780680560075 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2377.6439772116055 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2793.9699659780335 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 2795.6138692116197 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 2959.233763445481 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3561.3249106266417 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3992.2817091688476 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 4392.892604105914 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 4754.464291784987 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 5149.12766172525 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5449.200951406963 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5826.661566922809 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 6202.4630693935815 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 1 t_end: 6206.63130724268 stifler_frac: 0.0025
# Sampling result - Lam: 0.30000000000000004 N_rec: 397 t_end: 6560.928725610241 stifler_frac: 0.9925
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 168.05897301792228 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 170.04346304989778 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 269.67804497182357 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 458.34693599998934 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 566.5417308552747 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 961.1050928936912 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1336.7551221532372 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1676.9583599357902 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 2020.5951265912172 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2384.5254482690934 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2751.2828669029623 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2877.6784728945067 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3177.9301810890192 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3582.7750766799645 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 398 t_end: 3927.303017209534 stifler_frac: 0.995
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 4273.230972372519 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 4657.02105052343 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5003.467508931142 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 5352.122238713934 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5499.369228778485 stifler_frac: 1.0
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 301.38085057434364 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 360 t_end: 645.6390759555029 stifler_frac: 0.9
# Sampling result - Lam: 0.1 N_rec: 394 t_end: 1041.5141284543006 stifler_frac: 0.985
# Sampling result - Lam: 0.1 N_rec: 384 t_end: 1403.7407877970927 stifler_frac: 0.96
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 1578.101306998865 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 398 t_end: 2037.1330702020023 stifler_frac: 0.995
# Sampling result - Lam: 0.1 N_rec: 371 t_end: 2382.418335654299 stifler_frac: 0.9275
# Sampling result - Lam: 0.1 N_rec: 391 t_end: 2746.345085800463 stifler_frac: 0.9775
# Sampling result - Lam: 0.1 N_rec: 377 t_end: 3082.4599855131937 stifler_frac: 0.9425
# Sampling result - Lam: 0.1 N_rec: 386 t_end: 3443.0020051344804 stifler_frac: 0.965
# Sampling result - Lam: 0.1 N_rec: 399 t_end: 3858.0716675253516 stifler_frac: 0.9975
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 3886.8485737671517 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 4366.970401254094 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 392 t_end: 4743.636020609388 stifler_frac: 0.98
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 5168.84037105942 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 396 t_end: 5550.531378848813 stifler_frac: 0.99
# Sampling result - Lam: 0.1 N_rec: 389 t_end: 5954.663358636948 stifler_frac: 0.9725
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 5958.101229958384 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 5979.752747759611 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 373 t_end: 6181.668345711738 stifler_frac: 0.9325
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 387.362815238863 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 791.9858973360532 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1037.570232090044 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1650.791306234388 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 2028.2060212789077 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 2454.3148428278178 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 2814.7193000740945 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 3230.4159847518354 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 3635.0838804268155 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 3981.010966765609 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 398 t_end: 4199.262510660872 stifler_frac: 0.995
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 4200.822689284481 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 4601.695057617595 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 1 t_end: 4603.344456548227 stifler_frac: 0.0025
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 5004.539773181548 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 5400.791060707877 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 5786.348823003628 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 6245.109212420126 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 6620.742471051869 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 7007.998640733329 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 409.6896797215368 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 811.9272089733431 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1216.6659586335368 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 1646.364956753752 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2038.467086600791 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2156.649905370737 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2556.9159587417976 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2979.4869140407727 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3111.0550019321777 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 3497.4749800322043 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 3853.0708284961165 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 4275.174556411769 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 4668.636465592369 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 5065.040189975095 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5469.044266793113 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 5766.545003046095 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 6167.250115547443 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 6566.5513348185295 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 6961.930045639801 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 7331.99040357664 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 342.84140030835096 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 1 t_end: 344.39004876197873 stifler_frac: 0.0025
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 711.5506515137472 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1120.5162686728866 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1561.7335365560762 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1976.4526168999303 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2103.9747360503825 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2521.5190621323613 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3074.226101362609 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3509.557260367494 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 3880.461789836805 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 4256.870428064673 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 4638.9254648682445 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5031.847624298011 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5419.759808117026 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 5782.550607896746 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 6183.860709355739 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 6586.862401541202 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 6998.450742439058 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 7412.078232402849 stifler_frac: 1.0
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 436.02302702429535 stifler_frac: 0.97
# Sampling result - Lam: 0.1 N_rec: 383 t_end: 678.7461348714917 stifler_frac: 0.9575
# Sampling result - Lam: 0.1 N_rec: 6 t_end: 990.5387601914595 stifler_frac: 0.015
# Sampling result - Lam: 0.1 N_rec: 384 t_end: 1146.4996933942703 stifler_frac: 0.96
# Sampling result - Lam: 0.1 N_rec: 1 t_end: 1202.1928579852015 stifler_frac: 0.0025
# Sampling result - Lam: 0.1 N_rec: 388 t_end: 1321.7984382523114 stifler_frac: 0.97
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 442.80127541003554 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 713.2895661760053 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 399 t_end: 1215.0668172443939 stifler_frac: 0.9975
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1460.0478678765683 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 1894.5193293795123 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 400 t_end: 2382.1553350395084 stifler_frac: 1.0
# Sampling result - Lam: 0.2 N_rec: 2 t_end: 2415.7165146708767 stifler_frac: 0.005
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 425.63925249568985 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 15 t_end: 598.1010797397741 stifler_frac: 0.0375
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 702.2696709327192 stifler_frac: 1.0
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 1176.120251615779 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 1496.1498547809692 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 399 t_end: 1996.2612432798594 stifler_frac: 0.9975
# Sampling result - Lam: 0.30000000000000004 N_rec: 2 t_end: 2002.7428540909962 stifler_frac: 0.005
# Sampling result - Lam: 0.30000000000000004 N_rec: 400 t_end: 2334.556061548995 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 436.483553051375 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 883.0951748925702 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1275.3767295110997 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 1602.0064473538102 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2032.6278829182102 stifler_frac: 1.0
# Sampling result - Lam: 0.4 N_rec: 399 t_end: 2448.942123189429 stifler_frac: 0.9975
# Sampling result - Lam: 0.4 N_rec: 400 t_end: 2938.859873772873 stifler_frac: 1.0
